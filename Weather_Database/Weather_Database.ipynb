# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# %%
# generate the random latitudes and longitudes
# pack them as pairs by zipping them (lat_lngs) with the zip() function.


# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Unpack the lat_lngs zip object into a coordinates list
# By this way, create a set of random latitudes and longitudes once.

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Fetch and display first 5 results from the lat-lngs list
coordinates[0:5]
# Out:
# [(-87.24202075002164, 96.07520966825302),
#  (-25.072798195839965, 0.2872067753384613),
#  (-28.766152301684144, -95.92190083467987),
#  (35.305821041714466, -129.78537907060348),
#  (27.337430487775578, -164.43520919029538)]

# %%
# Match those coordinates up with cities.
# install citipy module before import it
# command line: pip install citipy

# %%
# Use the citipy module to determine nearest city and country based on latitude and longitude.
from citipy import citipy

# %%
# use the 2000 pairs of latitudes and longitudes we generate from our zip practice 
# to get a city and country code from the citipy module.

# create a for loop that will do the following:

# Iterate through the coordinates' zipped tuple.
# Use citipy.nearest_city() and inside it, 
# add the latitude and longitude in this format: coordinate[0], coordinate[1].
# To print the city name, chain the city_name to the nearest_city() function.
# To print the country name, chain the country_code to the nearest_city() function.

# Be sure cities are unique, add a decision statement with the logical operator "not in"
#  to determine whether the found city is already in the cities list

# first, create a list to store city names.
cities = []

for coordinate in coordinates:
    
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
   
    country = citipy.nearest_city(coordinate[0], coordinate[1]).country_code
    

    # If the city is unique, then  add it to the cities list.
    if city not in cities:
        cities.append(city)
        print( city, country)


# Print the city count to confirm sufficient count.
print(len(cities))

# Display the city list "cities"
cities[0:5]
# Out:
# albany au
# jamestown sh
# lebu cl
# ukiah us
# kapaa us
# tuktoyaktuk ca
# qeshm ir
# port alfred za
# basco ph
# aswan eg
# sibolga id
# taolanaro mg
# dunedin nz
# esperance au
# puerto ayora ec
# hobart au
# cabo san lucas mx
# mahebourg mu
# tromso no
# saskylakh ru
# rikitea pf
# vrangel ru
# vardo no
# ushuaia ar
# shar kz
# arlit ne
# bluff nz
# punta arenas cl
# parana ar
# salalah om
# tuggurt dz
# atuona pf
# attawapiskat ca
# atar mr
# bambous virieux mu
# hermanus za
# dikson ru
# qaanaaq gl
# vaini to
# cape town za
# salekhard ru
# vao nc
# pala td
# kodiak us
# saint george bm
# leshukonskoye ru
# matagami ca
# sobolevo ru
# caetite br
# victoria sc
# worland us
# talnakh ru
# tautira pf
# barentsburg sj
# yellowknife ca
# banjar id
# abramovka ru
# rawson ar
# lincoln ar
# hilo us
# avera pf
# vidalia us
# alofi nu
# upernavik gl
# pasighat in
# tiksi ru
# butaritari ki
# osmena ph
# bandarbeyla so
# vaitupu wf
# komsomolskiy ru
# sao gabriel da cachoeira br
# avarua ck
# requena pe
# eirunepe br
# ganzhou cn
# georgetown sh
# alice springs au
# christiansburg us
# barrow us
# mataura pf
# bud no
# rocha uy
# belushya guba ru
# kachiry kz
# sitka us
# bethel us
# illoqqortoormiut gl
# vasto it
# shevchenkove ua
# dingle ie
# ullapool gb
# montepuez mz
# busselton au
# thompson ca
# nome us
# el rincon hn
# sioux lookout ca
# airai pw
# obo cf
# sorland no
# kijang id
# muzaffarpur in
# yarada in
# olafsvik is
# sao joao da barra br
# qasigiannguit gl
# provideniya ru
# samusu ws
# tabuk sa
# east london za
# bredasdorp za
# tasiilaq gl
# ixtapa mx
# amderma ru
# hede cn
# kahului us
# torbay ca
# bogovarovo ru
# alyangula au
# smithers ca
# port elizabeth za
# murray bridge au
# sataua ws
# ruatoria nz
# harper lr
# omaha us
# cidreira br
# bengkulu id
# ponta delgada pt
# hambantota lk
# vaitape pf
# tabas ir
# san jose gt
# kabalo cd
# lowestoft gb
# kismayo so
# dauphin ca
# sola vu
# sao jose da coroa grande br
# mokhsogollokh ru
# pingliang cn
# asau tv
# vila velha br
# grand gaube mu
# katobu id
# sentyabrskiy ru
# manacapuru br
# urumqi cn
# itacare br
# montorio al vomano it
# rio gallegos ar
# santa rosa bo
# grand baie mu
# husavik is
# tay ninh vn
# klaksvik fo
# yerbogachen ru
# louisbourg ca
# nikolskoye ru
# lingyuan cn
# kerouane gn
# evensk ru
# tsihombe mg
# biabou vc
# new norfolk au
# dolbeau ca
# haimen cn
# kuusamo fi
# egvekinot ru
# yulara au
# tabukiniberu ki
# saleaula ws
# majene id
# kyabe td
# altagracia de orituco ve
# nshamba tz
# taoudenni ml
# havoysund no
# boyolangu id
# kapit my
# astoria us
# chokurdakh ru
# lorengau pg
# tobermory gb
# kaitangata nz
# dryden ca
# chokwe mz
# khatanga ru
# faya td
# ambon id
# qaqortoq gl
# sigayevo ru
# laramie us
# intipuca sv
# chapais ca
# penha br
# ahmadpur east pk
# wanning cn
# carnarvon au
# arraial do cabo br
# tigil ru
# erenhot cn
# verkhnevilyuysk ru
# hithadhoo mv
# coquimbo cl
# la romana do
# touros br
# lagoa pt
# marcona pe
# valparaiso cl
# manokwari id
# laguna br
# grand river south east mu
# aguai br
# kudahuvadhoo mv
# saint-philippe re
# conceicao do araguaia br
# rapid valley us
# haines junction ca
# awjilah ly
# teya ru
# santa cruz cr
# makakilo city us
# severo-kurilsk ru
# mar del plata ar
# umzimvubu za
# san cristobal ec
# karaul ru
# khonuu ru
# kavieng pg
# cockburn town bs
# kuche cn
# antofagasta cl
# road town vg
# heinola fi
# nizhneyansk ru
# buariki ki
# rio grande br
# camflora ph
# auki sb
# kruisfontein za
# poninka ua
# iqaluit ca
# prince rupert ca
# pisco pe
# kandrian pg
# teknaf bd
# ulundi za
# myanaung mm
# kalabo zm
# batagay ru
# maceio br
# berlevag no
# sorong id
# kununurra au
# sao filipe cv
# yemtsa ru
# montespertoli it
# kibaya tz
# fevralsk ru
# margate za
# gashua ng
# mys shmidta ru
# seoul kr
# camana pe
# aykhal ru
# mexico us
# port blair in
# codrington ag
# isangel vu
# chabahar ir
# luderitz na
# whitehorse ca
# ambulu id
# korla cn
# chimore bo
# namibe ao
# tumen cn
# maniitsoq gl
# galesong id
# guerrero negro mx
# neiafu to
# mangai cd
# yarmouth ca
# lompoc us
# troitsk ru
# kimbe pg
# geraldton au
# pevek ru
# port shepstone za
# moryakovskiy zaton ru
# la ronge ca
# yukhnov ru
# helena us
# islamkot pk
# palabuhanratu id
# lavrentiya ru
# castro cl
# adrar dz
# okha ru
# karaton kz
# port lincoln au
# jiddah sa
# katakwi ug
# ribeira grande pt
# muros es
# atasu kz
# port-gentil ga
# port hedland au
# pernik bg
# addison us
# diu in
# sid rs
# langenburg ca
# lamesa us
# port macquarie au
# los llanos de aridane es
# ponta do sol cv
# bako et
# cassia br
# dicabisagan ph
# dalen no
# labuhan id
# loiza us
# mount isa au
# ust-ishim ru
# dali cn
# belaya gora ru
# kushiro jp
# sur om
# zverinogolovskoye ru
# nanortalik gl
# ialibu pg
# lasa cn
# cayenne gf
# lima pe
# bonavista ca
# iracoubo gf
# marawi sd
# athabasca ca
# arman ru
# mumford gh
# ahipara nz
# lolua tv
# novyy urengoy ru
# morgantown us
# manoel urbano br
# hasaki jp
# buchs ch
# roros no
# port hawkesbury ca
# norman wells ca
# imbituba br
# college us
# katsiveli ua
# high level ca
# aanekoski fi
# iwanai jp
# san vicente ph
# veraval in
# wajima jp
# gat ly
# abu kamal sy
# nizhniy tsasuchey ru
# hami cn
# mount gambier au
# mehamn no
# aksu cn
# havelock us
# ebano mx
# lufilufi ws
# cherskiy ru
# launceston au
# economy us
# faanui pf
# svetlaya ru
# padang id
# portland au
# sambava mg
# labutta mm
# constitucion mx
# narsaq gl
# luba gq
# skelleftea se
# balikpapan id
# khuzdar pk
# souillac mu
# dutlwe bw
# istok ru
# kutum sd
# te anau nz
# chuy uy
# ambilobe mg
# bathsheba bb
# araouane ml
# callaguip ph
# agen fr
# beringovskiy ru
# yar-sale ru
# sihora in
# masvingo zw
# zyryanka ru
# bichura ru
# salinas ec
# yirol sd
# jalu ly
# salamanca cl
# coihaique cl
# sainte-anne-des-monts ca
# san patricio mx
# umm lajj sa
# pulandian cn
# kichera ru
# nantucket us
# lieksa fi
# samalaeulu ws
# la asuncion ve
# bardiyah ly
# fortuna us
# archidona ec
# griffith au
# inirida co
# da nang vn
# novoagansk ru
# kaili cn
# altamira br
# saint-joseph re
# matara lk
# gigmoto ph
# amapa br
# rawannawi ki
# pousat kh
# velikiy ustyug ru
# sangar ru
# pinega ru
# chernyshevskiy ru
# shubarshi kz
# gweta bw
# diapaga bf
# olonets ru
# petropavlovsk-kamchatskiy ru
# alugan ph
# port keats au
# meyungs pw
# soure br
# sept-iles ca
# kroya id
# huizhou cn
# krasavino ru
# alpena us
# chicama pe
# esfahan ir
# jatai br
# beboto td
# raymondville us
# ouango cf
# kokstad za
# soyo ao
# manbij sy
# kloulklubed pw
# the valley ai
# kenai us
# oistins bb
# kosa ru
# posadas ar
# victor harbor au
# itarema br
# grindavik is
# aflu dz
# baghmara in
# wilmington us
# aklavik ca
# longonjo ao
# bokspits bw
# san policarpo ph
# waipawa nz
# gejiu cn
# vredendal za
# acari pe
# zavetnoye ru
# fengcheng cn
# mizan teferi et
# cairns au
# kirya ru
# sorvag fo
# longyearbyen sj
# mundargi in
# saldanha za
# bargal so
# dakar sn
# miraflores co
# banda aceh id
# sayyan ye
# el sauzal mx
# san ml
# oktyabrskoye ru
# kyzyl-suu kg
# san andres co
# ostrovnoy ru
# ust-nera ru
# bima id
# clifton springs au
# inuvik ca
# kamenskoye ru
# hurghada eg
# sfantu gheorghe ro
# grenaa dk
# kumluca tr
# ndola zm
# bloemfontein za
# ancud cl
# kaeo nz
# trincomalee lk
# loa janan id
# tiznit ma
# samarai pg
# keningau my
# khowst af
# andrews us
# marinette us
# leningradskiy ru
# ilulissat gl
# omboue ga
# san bartolome de tirajana es
# caravelas br
# doctor pedro p. pena py
# fairmont us
# taltal cl
# kirakira sb
# diamantino br
# semnan ir
# ovruch ua
# burnie au
# fort nelson ca
# paamiut gl
# pochutla mx
# ketchikan us
# clyde river ca
# tarko-sale ru
# orlik ru
# maldonado uy
# la cruz mx
# varzelandia br
# berdigestyakh ru
# luanda ao
# bela pk
# zhigansk ru
# sivaki ru
# vung tau vn
# moose factory ca
# nicolas bravo mx
# lac-megantic ca
# chardara kz
# mendeleyevo ru
# haibowan cn
# yakeshi cn
# ahome mx
# novyy oskol ru
# karratha au
# meulaboh id
# kathmandu np
# nanakuli us
# vestmannaeyjar is
# shenxian cn
# newport us
# ampanihy mg
# godda in
# serenje zm
# vitim ru
# eureka us
# palmer us
# scarborough gb
# mae chan th
# marcon it
# necochea ar
# carutapera br
# dawson creek ca
# el seibo do
# flinders au
# mao td
# calca pe
# sabla bg
# elko us
# puerto escondido mx
# neropolis br
# hue vn
# ahar ir
# peraiyur in
# aasiaat gl
# buchanan lr
# kilis tr
# mtinko tz
# hamilton bm
# warmbad na
# hit iq
# jorpeland no
# bassano ca
# ous ru
# spirit river ca
# shingu jp
# malpe in
# zabol ir
# candido mendes br
# adamas gr
# murygino ru
# beypur in
# mormugao in
# hauterive ca
# bonthe sl
# brae gb
# sumter us
# novosil ru
# comodoro rivadavia ar
# varna ru
# yinchuan cn
# najran sa
# moyo ug
# bur gabo so
# macae br
# rutland us
# celestun mx
# viedma ar
# nechanice cz
# richards bay za
# champerico gt
# kupang id
# tonj sd
# kavaratti in
# novonikolayevskiy ru
# puerto baquerizo moreno ec
# kangaatsiaq gl
# suleja ng
# naze jp
# cheuskiny ru
# atherton au
# valente br
# krasnoselkup ru
# honiara sb
# gumdag tm
# nandrin be
# gallipoli it
# gallup us
# noumea nc
# ossora ru
# uyemskiy ru
# poum nc
# zambezi zm
# mount pleasant us
# namatanai pg
# lerwick gb
# wodonga au
# nuevo san juan parangaricutiro mx
# mont-de-marsan fr
# mackenzie ca
# dustlik uz
# ayagoz kz
# tamsalu ee
# goderich sl
# ust-kamchatsk ru
# anadyr ru
# hovd mn
# tumannyy ru
# cururupu br
# vagamo no
# sinnamary gf
# belluno it
# tura ru
# suluq ly
# petrozavodsk ru
# saint-pierre pm
# buon me thuot vn
# bilibino ru
# aketi cd
# saravan la
# abu jubayhah sd
# arua ug
# liusha cn
# guaiba br
# bolungarvik is
# praya id
# severnyy ru
# antalaha mg
# solovetskiy ru
# yenagoa ng
# yunhe cn
# mandalgovi mn
# fukue jp
# mitu co
# tidman ph
# metro id
# lulindi tz
# palu id
# vanderhoof ca
# dzhebariki-khaya ru
# bundaberg au
# jumla np
# hobyo so
# penzance gb
# san ramon bo
# henties bay na
# misratah ly
# pangnirtung ca
# syamzha ru
# moa cu
# mata cn
# otane nz
# ust-charyshskaya pristan ru
# san quintin mx
# sao luis de montes belos br
# phalaborwa za
# thinadhoo mv
# popondetta pg
# wanaka nz
# great falls us
# staryy nadym ru
# awash et
# dien bien vn
# port hardy ca
# amaga ph
# porto nacional br
# dharchula in
# hirara jp
# hampton ca
# fairbanks us
# mayo ca
# homer us
# shache cn
# hihifo to
# byron bay au
# ponoka ca
# quelimane mz
# uyuni bo
# koumac nc
# sabzevar ir
# forbes au
# srednekolymsk ru
# samarkand uz
# santa maria cv
# naron es
# christchurch gb
# mogadishu so
# kidal ml
# margosatubig ph
# half moon bay us
# marovoay mg
# taiyuan cn
# skibbereen ie
# 748
# ['albany', 'jamestown', 'lebu', 'ukiah', 'kapaa']

# %%
range(len(cities))
# Out:
# range(0, 748)

# %%
# 1 Use the OpenWeatherMap API to get the weather data for the database
# 2 Retrieve the weather from each city in the database

# %%
# Import more dependencies and API key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Initialize an Empty List and Counters

# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters for the iteration of the logging for each recorded response 
# and  set to start at 1.
record_count = 1
set_count = 1

# Iterate through list of cities and begin building the URL for each city, 
# while grouping our records in sets of 50.

# Loop through all the cities in our list.
# Every time we want to reference the city in our code, 
# we need to use the indexing on the cities list. 
# Unfortunately, this will cause programming errors when we are building the city_url 
# because it adds the index, not the city name, to the city_url. 
# To fix this issue, we need to create another for loop to get the city from the cities list.
# Instead of using two for loops, we can use the enumerate() method 
# as an alternative way to iterate through the list of cities 
# and retrieve both the index, and the city from the list. 


for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes. 
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city. replace space with"+" if ther is any
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    
    # Run an API request for each of the cities.
    # Add a try-except block to handle error to prevent the API request from stopping prematurely 
    # if the city_weather request isn't a valid response.类似于if then 格式
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_dsecription= city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        # 每一条要append的记录，就是一个城市信息的dictioanry
        # 这样，city_data 就包含了a list of dictionaries
        # 在之后放入DF 时， 按照row-oriented way, 将每个dict看做一条row的记录


        city_data.append({"City": city.title(),
                            "Country": city_country,
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Current Description":city_weather_dsecription
                            })

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | lebu
# Processing Record 4 of Set 1 | ukiah
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | tuktoyaktuk
# Processing Record 7 of Set 1 | qeshm
# Processing Record 8 of Set 1 | port alfred
# Processing Record 9 of Set 1 | basco
# Processing Record 10 of Set 1 | aswan
# Processing Record 11 of Set 1 | sibolga
# Processing Record 12 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 1 | dunedin
# Processing Record 14 of Set 1 | esperance
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | hobart
# Processing Record 17 of Set 1 | cabo san lucas
# Processing Record 18 of Set 1 | mahebourg
# Processing Record 19 of Set 1 | tromso
# Processing Record 20 of Set 1 | saskylakh
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | vrangel
# Processing Record 23 of Set 1 | vardo
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | shar
# Processing Record 26 of Set 1 | arlit
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | parana
# Processing Record 30 of Set 1 | salalah
# Processing Record 31 of Set 1 | tuggurt
# City not found. Skipping...
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 1 | atar
# Processing Record 35 of Set 1 | bambous virieux
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | dikson
# Processing Record 38 of Set 1 | qaanaaq
# Processing Record 39 of Set 1 | vaini
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | salekhard
# Processing Record 42 of Set 1 | vao
# Processing Record 43 of Set 1 | pala
# Processing Record 44 of Set 1 | kodiak
# Processing Record 45 of Set 1 | saint george
# Processing Record 46 of Set 1 | leshukonskoye
# Processing Record 47 of Set 1 | matagami
# Processing Record 48 of Set 1 | sobolevo
# Processing Record 49 of Set 1 | caetite
# Processing Record 50 of Set 1 | victoria
# Processing Record 1 of Set 2 | worland
# Processing Record 2 of Set 2 | talnakh
# Processing Record 3 of Set 2 | tautira
# Processing Record 4 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 2 | yellowknife
# Processing Record 6 of Set 2 | banjar
# Processing Record 7 of Set 2 | abramovka
# Processing Record 8 of Set 2 | rawson
# Processing Record 9 of Set 2 | lincoln
# Processing Record 10 of Set 2 | hilo
# Processing Record 11 of Set 2 | avera
# Processing Record 12 of Set 2 | vidalia
# Processing Record 13 of Set 2 | alofi
# Processing Record 14 of Set 2 | upernavik
# Processing Record 15 of Set 2 | pasighat
# Processing Record 16 of Set 2 | tiksi
# Processing Record 17 of Set 2 | butaritari
# Processing Record 18 of Set 2 | osmena
# Processing Record 19 of Set 2 | bandarbeyla
# Processing Record 20 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 2 | komsomolskiy
# Processing Record 22 of Set 2 | sao gabriel da cachoeira
# Processing Record 23 of Set 2 | avarua
# Processing Record 24 of Set 2 | requena
# Processing Record 25 of Set 2 | eirunepe
# Processing Record 26 of Set 2 | ganzhou
# Processing Record 27 of Set 2 | georgetown
# Processing Record 28 of Set 2 | alice springs
# Processing Record 29 of Set 2 | christiansburg
# Processing Record 30 of Set 2 | barrow
# Processing Record 31 of Set 2 | mataura
# Processing Record 32 of Set 2 | bud
# Processing Record 33 of Set 2 | rocha
# Processing Record 34 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 2 | kachiry
# Processing Record 36 of Set 2 | sitka
# Processing Record 37 of Set 2 | bethel
# Processing Record 38 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 2 | vasto
# Processing Record 40 of Set 2 | shevchenkove
# Processing Record 41 of Set 2 | dingle
# Processing Record 42 of Set 2 | ullapool
# Processing Record 43 of Set 2 | montepuez
# Processing Record 44 of Set 2 | busselton
# Processing Record 45 of Set 2 | thompson
# Processing Record 46 of Set 2 | nome
# Processing Record 47 of Set 2 | el rincon
# Processing Record 48 of Set 2 | sioux lookout
# Processing Record 49 of Set 2 | airai
# Processing Record 50 of Set 2 | obo
# Processing Record 1 of Set 3 | sorland
# Processing Record 2 of Set 3 | kijang
# Processing Record 3 of Set 3 | muzaffarpur
# Processing Record 4 of Set 3 | yarada
# Processing Record 5 of Set 3 | olafsvik
# Processing Record 6 of Set 3 | sao joao da barra
# Processing Record 7 of Set 3 | qasigiannguit
# Processing Record 8 of Set 3 | provideniya
# Processing Record 9 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 3 | tabuk
# Processing Record 11 of Set 3 | east london
# Processing Record 12 of Set 3 | bredasdorp
# Processing Record 13 of Set 3 | tasiilaq
# Processing Record 14 of Set 3 | ixtapa
# Processing Record 15 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 3 | hede
# Processing Record 17 of Set 3 | kahului
# Processing Record 18 of Set 3 | torbay
# Processing Record 19 of Set 3 | bogovarovo
# Processing Record 20 of Set 3 | alyangula
# Processing Record 21 of Set 3 | smithers
# Processing Record 22 of Set 3 | port elizabeth
# Processing Record 23 of Set 3 | murray bridge
# Processing Record 24 of Set 3 | sataua
# City not found. Skipping...
# Processing Record 25 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 26 of Set 3 | harper
# Processing Record 27 of Set 3 | omaha
# Processing Record 28 of Set 3 | cidreira
# Processing Record 29 of Set 3 | bengkulu
# Processing Record 30 of Set 3 | ponta delgada
# Processing Record 31 of Set 3 | hambantota
# Processing Record 32 of Set 3 | vaitape
# Processing Record 33 of Set 3 | tabas
# Processing Record 34 of Set 3 | san jose
# Processing Record 35 of Set 3 | kabalo
# Processing Record 36 of Set 3 | lowestoft
# Processing Record 37 of Set 3 | kismayo
# Processing Record 38 of Set 3 | dauphin
# Processing Record 39 of Set 3 | sola
# Processing Record 40 of Set 3 | sao jose da coroa grande
# Processing Record 41 of Set 3 | mokhsogollokh
# Processing Record 42 of Set 3 | pingliang
# Processing Record 43 of Set 3 | asau
# Processing Record 44 of Set 3 | vila velha
# Processing Record 45 of Set 3 | grand gaube
# Processing Record 46 of Set 3 | katobu
# Processing Record 47 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 3 | manacapuru
# Processing Record 49 of Set 3 | urumqi
# Processing Record 50 of Set 3 | itacare
# Processing Record 1 of Set 4 | montorio al vomano
# Processing Record 2 of Set 4 | rio gallegos
# Processing Record 3 of Set 4 | santa rosa
# Processing Record 4 of Set 4 | grand baie
# Processing Record 5 of Set 4 | husavik
# Processing Record 6 of Set 4 | tay ninh
# Processing Record 7 of Set 4 | klaksvik
# Processing Record 8 of Set 4 | yerbogachen
# Processing Record 9 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 10 of Set 4 | nikolskoye
# Processing Record 11 of Set 4 | lingyuan
# Processing Record 12 of Set 4 | kerouane
# Processing Record 13 of Set 4 | evensk
# Processing Record 14 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 4 | biabou
# Processing Record 16 of Set 4 | new norfolk
# Processing Record 17 of Set 4 | dolbeau
# City not found. Skipping...
# Processing Record 18 of Set 4 | haimen
# Processing Record 19 of Set 4 | kuusamo
# Processing Record 20 of Set 4 | egvekinot
# Processing Record 21 of Set 4 | yulara
# Processing Record 22 of Set 4 | tabukiniberu
# City not found. Skipping...
# Processing Record 23 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 4 | majene
# Processing Record 25 of Set 4 | kyabe
# Processing Record 26 of Set 4 | altagracia de orituco
# Processing Record 27 of Set 4 | nshamba
# Processing Record 28 of Set 4 | taoudenni
# Processing Record 29 of Set 4 | havoysund
# Processing Record 30 of Set 4 | boyolangu
# Processing Record 31 of Set 4 | kapit
# Processing Record 32 of Set 4 | astoria
# Processing Record 33 of Set 4 | chokurdakh
# Processing Record 34 of Set 4 | lorengau
# Processing Record 35 of Set 4 | tobermory
# Processing Record 36 of Set 4 | kaitangata
# Processing Record 37 of Set 4 | dryden
# Processing Record 38 of Set 4 | chokwe
# Processing Record 39 of Set 4 | khatanga
# Processing Record 40 of Set 4 | faya
# Processing Record 41 of Set 4 | ambon
# Processing Record 42 of Set 4 | qaqortoq
# Processing Record 43 of Set 4 | sigayevo
# Processing Record 44 of Set 4 | laramie
# Processing Record 45 of Set 4 | intipuca
# Processing Record 46 of Set 4 | chapais
# Processing Record 47 of Set 4 | penha
# Processing Record 48 of Set 4 | ahmadpur east
# Processing Record 49 of Set 4 | wanning
# Processing Record 50 of Set 4 | carnarvon
# Processing Record 1 of Set 5 | arraial do cabo
# Processing Record 2 of Set 5 | tigil
# Processing Record 3 of Set 5 | erenhot
# Processing Record 4 of Set 5 | verkhnevilyuysk
# Processing Record 5 of Set 5 | hithadhoo
# Processing Record 6 of Set 5 | coquimbo
# Processing Record 7 of Set 5 | la romana
# Processing Record 8 of Set 5 | touros
# Processing Record 9 of Set 5 | lagoa
# Processing Record 10 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 5 | valparaiso
# Processing Record 12 of Set 5 | manokwari
# Processing Record 13 of Set 5 | laguna
# Processing Record 14 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 5 | aguai
# Processing Record 16 of Set 5 | kudahuvadhoo
# Processing Record 17 of Set 5 | saint-philippe
# Processing Record 18 of Set 5 | conceicao do araguaia
# Processing Record 19 of Set 5 | rapid valley
# Processing Record 20 of Set 5 | haines junction
# Processing Record 21 of Set 5 | awjilah
# Processing Record 22 of Set 5 | teya
# Processing Record 23 of Set 5 | santa cruz
# Processing Record 24 of Set 5 | makakilo city
# Processing Record 25 of Set 5 | severo-kurilsk
# Processing Record 26 of Set 5 | mar del plata
# Processing Record 27 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 5 | san cristobal
# Processing Record 29 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 30 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 31 of Set 5 | kavieng
# Processing Record 32 of Set 5 | cockburn town
# Processing Record 33 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 5 | antofagasta
# Processing Record 35 of Set 5 | road town
# Processing Record 36 of Set 5 | heinola
# Processing Record 37 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 5 | buariki
# City not found. Skipping...
# Processing Record 39 of Set 5 | rio grande
# Processing Record 40 of Set 5 | camflora
# City not found. Skipping...
# Processing Record 41 of Set 5 | auki
# Processing Record 42 of Set 5 | kruisfontein
# Processing Record 43 of Set 5 | poninka
# Processing Record 44 of Set 5 | iqaluit
# Processing Record 45 of Set 5 | prince rupert
# Processing Record 46 of Set 5 | pisco
# Processing Record 47 of Set 5 | kandrian
# Processing Record 48 of Set 5 | teknaf
# Processing Record 49 of Set 5 | ulundi
# Processing Record 50 of Set 5 | myanaung
# Processing Record 1 of Set 6 | kalabo
# Processing Record 2 of Set 6 | batagay
# Processing Record 3 of Set 6 | maceio
# Processing Record 4 of Set 6 | berlevag
# Processing Record 5 of Set 6 | sorong
# Processing Record 6 of Set 6 | kununurra
# Processing Record 7 of Set 6 | sao filipe
# Processing Record 8 of Set 6 | yemtsa
# Processing Record 9 of Set 6 | montespertoli
# Processing Record 10 of Set 6 | kibaya
# Processing Record 11 of Set 6 | fevralsk
# City not found. Skipping...
# Processing Record 12 of Set 6 | margate
# Processing Record 13 of Set 6 | gashua
# Processing Record 14 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 6 | seoul
# Processing Record 16 of Set 6 | camana
# Processing Record 17 of Set 6 | aykhal
# Processing Record 18 of Set 6 | mexico
# Processing Record 19 of Set 6 | port blair
# Processing Record 20 of Set 6 | codrington
# Processing Record 21 of Set 6 | isangel
# Processing Record 22 of Set 6 | chabahar
# Processing Record 23 of Set 6 | luderitz
# Processing Record 24 of Set 6 | whitehorse
# Processing Record 25 of Set 6 | ambulu
# Processing Record 26 of Set 6 | korla
# Processing Record 27 of Set 6 | chimore
# Processing Record 28 of Set 6 | namibe
# Processing Record 29 of Set 6 | tumen
# Processing Record 30 of Set 6 | maniitsoq
# Processing Record 31 of Set 6 | galesong
# Processing Record 32 of Set 6 | guerrero negro
# Processing Record 33 of Set 6 | neiafu
# Processing Record 34 of Set 6 | mangai
# Processing Record 35 of Set 6 | yarmouth
# Processing Record 36 of Set 6 | lompoc
# Processing Record 37 of Set 6 | troitsk
# Processing Record 38 of Set 6 | kimbe
# Processing Record 39 of Set 6 | geraldton
# Processing Record 40 of Set 6 | pevek
# Processing Record 41 of Set 6 | port shepstone
# Processing Record 42 of Set 6 | moryakovskiy zaton
# Processing Record 43 of Set 6 | la ronge
# Processing Record 44 of Set 6 | yukhnov
# Processing Record 45 of Set 6 | helena
# Processing Record 46 of Set 6 | islamkot
# Processing Record 47 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 6 | lavrentiya
# Processing Record 49 of Set 6 | castro
# Processing Record 50 of Set 6 | adrar
# Processing Record 1 of Set 7 | okha
# Processing Record 2 of Set 7 | karaton
# Processing Record 3 of Set 7 | port lincoln
# Processing Record 4 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 5 of Set 7 | katakwi
# Processing Record 6 of Set 7 | ribeira grande
# Processing Record 7 of Set 7 | muros
# Processing Record 8 of Set 7 | atasu
# Processing Record 9 of Set 7 | port-gentil
# Processing Record 10 of Set 7 | port hedland
# Processing Record 11 of Set 7 | pernik
# Processing Record 12 of Set 7 | addison
# Processing Record 13 of Set 7 | diu
# Processing Record 14 of Set 7 | sid
# Processing Record 15 of Set 7 | langenburg
# Processing Record 16 of Set 7 | lamesa
# Processing Record 17 of Set 7 | port macquarie
# Processing Record 18 of Set 7 | los llanos de aridane
# Processing Record 19 of Set 7 | ponta do sol
# Processing Record 20 of Set 7 | bako
# Processing Record 21 of Set 7 | cassia
# Processing Record 22 of Set 7 | dicabisagan
# Processing Record 23 of Set 7 | dalen
# Processing Record 24 of Set 7 | labuhan
# Processing Record 25 of Set 7 | loiza
# Processing Record 26 of Set 7 | mount isa
# Processing Record 27 of Set 7 | ust-ishim
# Processing Record 28 of Set 7 | dali
# Processing Record 29 of Set 7 | belaya gora
# Processing Record 30 of Set 7 | kushiro
# Processing Record 31 of Set 7 | sur
# Processing Record 32 of Set 7 | zverinogolovskoye
# Processing Record 33 of Set 7 | nanortalik
# Processing Record 34 of Set 7 | ialibu
# Processing Record 35 of Set 7 | lasa
# Processing Record 36 of Set 7 | cayenne
# Processing Record 37 of Set 7 | lima
# Processing Record 38 of Set 7 | bonavista
# Processing Record 39 of Set 7 | iracoubo
# Processing Record 40 of Set 7 | marawi
# Processing Record 41 of Set 7 | athabasca
# Processing Record 42 of Set 7 | arman
# Processing Record 43 of Set 7 | mumford
# Processing Record 44 of Set 7 | ahipara
# Processing Record 45 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 7 | novyy urengoy
# Processing Record 47 of Set 7 | morgantown
# Processing Record 48 of Set 7 | manoel urbano
# Processing Record 49 of Set 7 | hasaki
# Processing Record 50 of Set 7 | buchs
# Processing Record 1 of Set 8 | roros
# Processing Record 2 of Set 8 | port hawkesbury
# Processing Record 3 of Set 8 | norman wells
# Processing Record 4 of Set 8 | imbituba
# Processing Record 5 of Set 8 | college
# Processing Record 6 of Set 8 | katsiveli
# City not found. Skipping...
# Processing Record 7 of Set 8 | high level
# Processing Record 8 of Set 8 | aanekoski
# Processing Record 9 of Set 8 | iwanai
# Processing Record 10 of Set 8 | san vicente
# Processing Record 11 of Set 8 | veraval
# Processing Record 12 of Set 8 | wajima
# Processing Record 13 of Set 8 | gat
# Processing Record 14 of Set 8 | abu kamal
# Processing Record 15 of Set 8 | nizhniy tsasuchey
# Processing Record 16 of Set 8 | hami
# Processing Record 17 of Set 8 | mount gambier
# Processing Record 18 of Set 8 | mehamn
# Processing Record 19 of Set 8 | aksu
# Processing Record 20 of Set 8 | havelock
# Processing Record 21 of Set 8 | ebano
# City not found. Skipping...
# Processing Record 22 of Set 8 | lufilufi
# Processing Record 23 of Set 8 | cherskiy
# Processing Record 24 of Set 8 | launceston
# Processing Record 25 of Set 8 | economy
# Processing Record 26 of Set 8 | faanui
# Processing Record 27 of Set 8 | svetlaya
# Processing Record 28 of Set 8 | padang
# Processing Record 29 of Set 8 | portland
# Processing Record 30 of Set 8 | sambava
# Processing Record 31 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 32 of Set 8 | constitucion
# Processing Record 33 of Set 8 | narsaq
# Processing Record 34 of Set 8 | luba
# Processing Record 35 of Set 8 | skelleftea
# Processing Record 36 of Set 8 | balikpapan
# Processing Record 37 of Set 8 | khuzdar
# Processing Record 38 of Set 8 | souillac
# Processing Record 39 of Set 8 | dutlwe
# Processing Record 40 of Set 8 | istok
# Processing Record 41 of Set 8 | kutum
# Processing Record 42 of Set 8 | te anau
# Processing Record 43 of Set 8 | chuy
# Processing Record 44 of Set 8 | ambilobe
# Processing Record 45 of Set 8 | bathsheba
# Processing Record 46 of Set 8 | araouane
# Processing Record 47 of Set 8 | callaguip
# Processing Record 48 of Set 8 | agen
# Processing Record 49 of Set 8 | beringovskiy
# Processing Record 50 of Set 8 | yar-sale
# Processing Record 1 of Set 9 | sihora
# Processing Record 2 of Set 9 | masvingo
# Processing Record 3 of Set 9 | zyryanka
# Processing Record 4 of Set 9 | bichura
# Processing Record 5 of Set 9 | salinas
# Processing Record 6 of Set 9 | yirol
# City not found. Skipping...
# Processing Record 7 of Set 9 | jalu
# Processing Record 8 of Set 9 | salamanca
# Processing Record 9 of Set 9 | coihaique
# Processing Record 10 of Set 9 | sainte-anne-des-monts
# Processing Record 11 of Set 9 | san patricio
# Processing Record 12 of Set 9 | umm lajj
# Processing Record 13 of Set 9 | pulandian
# Processing Record 14 of Set 9 | kichera
# Processing Record 15 of Set 9 | nantucket
# Processing Record 16 of Set 9 | lieksa
# Processing Record 17 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 18 of Set 9 | la asuncion
# Processing Record 19 of Set 9 | bardiyah
# Processing Record 20 of Set 9 | fortuna
# Processing Record 21 of Set 9 | archidona
# Processing Record 22 of Set 9 | griffith
# Processing Record 23 of Set 9 | inirida
# Processing Record 24 of Set 9 | da nang
# Processing Record 25 of Set 9 | novoagansk
# Processing Record 26 of Set 9 | kaili
# Processing Record 27 of Set 9 | altamira
# Processing Record 28 of Set 9 | saint-joseph
# Processing Record 29 of Set 9 | matara
# Processing Record 30 of Set 9 | gigmoto
# Processing Record 31 of Set 9 | amapa
# Processing Record 32 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 33 of Set 9 | pousat
# City not found. Skipping...
# Processing Record 34 of Set 9 | velikiy ustyug
# Processing Record 35 of Set 9 | sangar
# Processing Record 36 of Set 9 | pinega
# Processing Record 37 of Set 9 | chernyshevskiy
# Processing Record 38 of Set 9 | shubarshi
# Processing Record 39 of Set 9 | gweta
# Processing Record 40 of Set 9 | diapaga
# Processing Record 41 of Set 9 | olonets
# Processing Record 42 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 9 | alugan
# Processing Record 44 of Set 9 | port keats
# Processing Record 45 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 46 of Set 9 | soure
# Processing Record 47 of Set 9 | sept-iles
# Processing Record 48 of Set 9 | kroya
# Processing Record 49 of Set 9 | huizhou
# Processing Record 50 of Set 9 | krasavino
# Processing Record 1 of Set 10 | alpena
# Processing Record 2 of Set 10 | chicama
# Processing Record 3 of Set 10 | esfahan
# Processing Record 4 of Set 10 | jatai
# Processing Record 5 of Set 10 | beboto
# Processing Record 6 of Set 10 | raymondville
# Processing Record 7 of Set 10 | ouango
# Processing Record 8 of Set 10 | kokstad
# Processing Record 9 of Set 10 | soyo
# Processing Record 10 of Set 10 | manbij
# Processing Record 11 of Set 10 | kloulklubed
# Processing Record 12 of Set 10 | the valley
# Processing Record 13 of Set 10 | kenai
# Processing Record 14 of Set 10 | oistins
# Processing Record 15 of Set 10 | kosa
# Processing Record 16 of Set 10 | posadas
# Processing Record 17 of Set 10 | victor harbor
# Processing Record 18 of Set 10 | itarema
# Processing Record 19 of Set 10 | grindavik
# Processing Record 20 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 21 of Set 10 | baghmara
# Processing Record 22 of Set 10 | wilmington
# Processing Record 23 of Set 10 | aklavik
# Processing Record 24 of Set 10 | longonjo
# Processing Record 25 of Set 10 | bokspits
# City not found. Skipping...
# Processing Record 26 of Set 10 | san policarpo
# Processing Record 27 of Set 10 | waipawa
# Processing Record 28 of Set 10 | gejiu
# Processing Record 29 of Set 10 | vredendal
# Processing Record 30 of Set 10 | acari
# Processing Record 31 of Set 10 | zavetnoye
# Processing Record 32 of Set 10 | fengcheng
# Processing Record 33 of Set 10 | mizan teferi
# Processing Record 34 of Set 10 | cairns
# Processing Record 35 of Set 10 | kirya
# Processing Record 36 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 37 of Set 10 | longyearbyen
# Processing Record 38 of Set 10 | mundargi
# Processing Record 39 of Set 10 | saldanha
# Processing Record 40 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 41 of Set 10 | dakar
# Processing Record 42 of Set 10 | miraflores
# Processing Record 43 of Set 10 | banda aceh
# Processing Record 44 of Set 10 | sayyan
# Processing Record 45 of Set 10 | el sauzal
# Processing Record 46 of Set 10 | san
# Processing Record 47 of Set 10 | oktyabrskoye
# Processing Record 48 of Set 10 | kyzyl-suu
# Processing Record 49 of Set 10 | san andres
# Processing Record 50 of Set 10 | ostrovnoy
# Processing Record 1 of Set 11 | ust-nera
# Processing Record 2 of Set 11 | bima
# Processing Record 3 of Set 11 | clifton springs
# Processing Record 4 of Set 11 | inuvik
# Processing Record 5 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 6 of Set 11 | hurghada
# Processing Record 7 of Set 11 | sfantu gheorghe
# Processing Record 8 of Set 11 | grenaa
# Processing Record 9 of Set 11 | kumluca
# Processing Record 10 of Set 11 | ndola
# Processing Record 11 of Set 11 | bloemfontein
# Processing Record 12 of Set 11 | ancud
# Processing Record 13 of Set 11 | kaeo
# Processing Record 14 of Set 11 | trincomalee
# Processing Record 15 of Set 11 | loa janan
# Processing Record 16 of Set 11 | tiznit
# Processing Record 17 of Set 11 | samarai
# Processing Record 18 of Set 11 | keningau
# Processing Record 19 of Set 11 | khowst
# Processing Record 20 of Set 11 | andrews
# Processing Record 21 of Set 11 | marinette
# Processing Record 22 of Set 11 | leningradskiy
# Processing Record 23 of Set 11 | ilulissat
# Processing Record 24 of Set 11 | omboue
# Processing Record 25 of Set 11 | san bartolome de tirajana
# Processing Record 26 of Set 11 | caravelas
# Processing Record 27 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 28 of Set 11 | fairmont
# Processing Record 29 of Set 11 | taltal
# Processing Record 30 of Set 11 | kirakira
# Processing Record 31 of Set 11 | diamantino
# Processing Record 32 of Set 11 | semnan
# Processing Record 33 of Set 11 | ovruch
# Processing Record 34 of Set 11 | burnie
# Processing Record 35 of Set 11 | fort nelson
# Processing Record 36 of Set 11 | paamiut
# Processing Record 37 of Set 11 | pochutla
# Processing Record 38 of Set 11 | ketchikan
# Processing Record 39 of Set 11 | clyde river
# Processing Record 40 of Set 11 | tarko-sale
# Processing Record 41 of Set 11 | orlik
# Processing Record 42 of Set 11 | maldonado
# Processing Record 43 of Set 11 | la cruz
# Processing Record 44 of Set 11 | varzelandia
# Processing Record 45 of Set 11 | berdigestyakh
# Processing Record 46 of Set 11 | luanda
# Processing Record 47 of Set 11 | bela
# Processing Record 48 of Set 11 | zhigansk
# Processing Record 49 of Set 11 | sivaki
# Processing Record 50 of Set 11 | vung tau
# Processing Record 1 of Set 12 | moose factory
# Processing Record 2 of Set 12 | nicolas bravo
# Processing Record 3 of Set 12 | lac-megantic
# Processing Record 4 of Set 12 | chardara
# Processing Record 5 of Set 12 | mendeleyevo
# Processing Record 6 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 7 of Set 12 | yakeshi
# Processing Record 8 of Set 12 | ahome
# Processing Record 9 of Set 12 | novyy oskol
# Processing Record 10 of Set 12 | karratha
# Processing Record 11 of Set 12 | meulaboh
# Processing Record 12 of Set 12 | kathmandu
# Processing Record 13 of Set 12 | nanakuli
# Processing Record 14 of Set 12 | vestmannaeyjar
# Processing Record 15 of Set 12 | shenxian
# Processing Record 16 of Set 12 | newport
# Processing Record 17 of Set 12 | ampanihy
# Processing Record 18 of Set 12 | godda
# Processing Record 19 of Set 12 | serenje
# Processing Record 20 of Set 12 | vitim
# Processing Record 21 of Set 12 | eureka
# Processing Record 22 of Set 12 | palmer
# Processing Record 23 of Set 12 | scarborough
# Processing Record 24 of Set 12 | mae chan
# Processing Record 25 of Set 12 | marcon
# Processing Record 26 of Set 12 | necochea
# Processing Record 27 of Set 12 | carutapera
# Processing Record 28 of Set 12 | dawson creek
# Processing Record 29 of Set 12 | el seibo
# Processing Record 30 of Set 12 | flinders
# Processing Record 31 of Set 12 | mao
# Processing Record 32 of Set 12 | calca
# Processing Record 33 of Set 12 | sabla
# Processing Record 34 of Set 12 | elko
# Processing Record 35 of Set 12 | puerto escondido
# Processing Record 36 of Set 12 | neropolis
# Processing Record 37 of Set 12 | hue
# Processing Record 38 of Set 12 | ahar
# Processing Record 39 of Set 12 | peraiyur
# Processing Record 40 of Set 12 | aasiaat
# Processing Record 41 of Set 12 | buchanan
# Processing Record 42 of Set 12 | kilis
# Processing Record 43 of Set 12 | mtinko
# Processing Record 44 of Set 12 | hamilton
# Processing Record 45 of Set 12 | warmbad
# Processing Record 46 of Set 12 | hit
# Processing Record 47 of Set 12 | jorpeland
# Processing Record 48 of Set 12 | bassano
# Processing Record 49 of Set 12 | ous
# Processing Record 50 of Set 12 | spirit river
# Processing Record 1 of Set 13 | shingu
# Processing Record 2 of Set 13 | malpe
# Processing Record 3 of Set 13 | zabol
# Processing Record 4 of Set 13 | candido mendes
# Processing Record 5 of Set 13 | adamas
# Processing Record 6 of Set 13 | murygino
# Processing Record 7 of Set 13 | beypur
# City not found. Skipping...
# Processing Record 8 of Set 13 | mormugao
# Processing Record 9 of Set 13 | hauterive
# Processing Record 10 of Set 13 | bonthe
# Processing Record 11 of Set 13 | brae
# Processing Record 12 of Set 13 | sumter
# Processing Record 13 of Set 13 | novosil
# Processing Record 14 of Set 13 | comodoro rivadavia
# Processing Record 15 of Set 13 | varna
# Processing Record 16 of Set 13 | yinchuan
# Processing Record 17 of Set 13 | najran
# Processing Record 18 of Set 13 | moyo
# Processing Record 19 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 20 of Set 13 | macae
# Processing Record 21 of Set 13 | rutland
# Processing Record 22 of Set 13 | celestun
# Processing Record 23 of Set 13 | viedma
# Processing Record 24 of Set 13 | nechanice
# Processing Record 25 of Set 13 | richards bay
# Processing Record 26 of Set 13 | champerico
# Processing Record 27 of Set 13 | kupang
# Processing Record 28 of Set 13 | tonj
# Processing Record 29 of Set 13 | kavaratti
# Processing Record 30 of Set 13 | novonikolayevskiy
# Processing Record 31 of Set 13 | puerto baquerizo moreno
# Processing Record 32 of Set 13 | kangaatsiaq
# Processing Record 33 of Set 13 | suleja
# Processing Record 34 of Set 13 | naze
# Processing Record 35 of Set 13 | cheuskiny
# City not found. Skipping...
# Processing Record 36 of Set 13 | atherton
# Processing Record 37 of Set 13 | valente
# Processing Record 38 of Set 13 | krasnoselkup
# Processing Record 39 of Set 13 | honiara
# Processing Record 40 of Set 13 | gumdag
# Processing Record 41 of Set 13 | nandrin
# Processing Record 42 of Set 13 | gallipoli
# Processing Record 43 of Set 13 | gallup
# Processing Record 44 of Set 13 | noumea
# Processing Record 45 of Set 13 | ossora
# Processing Record 46 of Set 13 | uyemskiy
# Processing Record 47 of Set 13 | poum
# Processing Record 48 of Set 13 | zambezi
# Processing Record 49 of Set 13 | mount pleasant
# Processing Record 50 of Set 13 | namatanai
# Processing Record 1 of Set 14 | lerwick
# Processing Record 2 of Set 14 | wodonga
# Processing Record 3 of Set 14 | nuevo san juan parangaricutiro
# Processing Record 4 of Set 14 | mont-de-marsan
# Processing Record 5 of Set 14 | mackenzie
# Processing Record 6 of Set 14 | dustlik
# Processing Record 7 of Set 14 | ayagoz
# Processing Record 8 of Set 14 | tamsalu
# Processing Record 9 of Set 14 | goderich
# Processing Record 10 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 11 of Set 14 | anadyr
# Processing Record 12 of Set 14 | hovd
# Processing Record 13 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 14 | cururupu
# Processing Record 15 of Set 14 | vagamo
# Processing Record 16 of Set 14 | sinnamary
# Processing Record 17 of Set 14 | belluno
# Processing Record 18 of Set 14 | tura
# Processing Record 19 of Set 14 | suluq
# Processing Record 20 of Set 14 | petrozavodsk
# Processing Record 21 of Set 14 | saint-pierre
# Processing Record 22 of Set 14 | buon me thuot
# City not found. Skipping...
# Processing Record 23 of Set 14 | bilibino
# Processing Record 24 of Set 14 | aketi
# Processing Record 25 of Set 14 | saravan
# Processing Record 26 of Set 14 | abu jubayhah
# City not found. Skipping...
# Processing Record 27 of Set 14 | arua
# Processing Record 28 of Set 14 | liusha
# Processing Record 29 of Set 14 | guaiba
# Processing Record 30 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 14 | praya
# Processing Record 32 of Set 14 | severnyy
# Processing Record 33 of Set 14 | antalaha
# Processing Record 34 of Set 14 | solovetskiy
# City not found. Skipping...
# Processing Record 35 of Set 14 | yenagoa
# Processing Record 36 of Set 14 | yunhe
# Processing Record 37 of Set 14 | mandalgovi
# Processing Record 38 of Set 14 | fukue
# Processing Record 39 of Set 14 | mitu
# Processing Record 40 of Set 14 | tidman
# Processing Record 41 of Set 14 | metro
# Processing Record 42 of Set 14 | lulindi
# Processing Record 43 of Set 14 | palu
# Processing Record 44 of Set 14 | vanderhoof
# Processing Record 45 of Set 14 | dzhebariki-khaya
# Processing Record 46 of Set 14 | bundaberg
# Processing Record 47 of Set 14 | jumla
# Processing Record 48 of Set 14 | hobyo
# Processing Record 49 of Set 14 | penzance
# Processing Record 50 of Set 14 | san ramon
# Processing Record 1 of Set 15 | henties bay
# Processing Record 2 of Set 15 | misratah
# Processing Record 3 of Set 15 | pangnirtung
# Processing Record 4 of Set 15 | syamzha
# Processing Record 5 of Set 15 | moa
# Processing Record 6 of Set 15 | mata
# Processing Record 7 of Set 15 | otane
# Processing Record 8 of Set 15 | ust-charyshskaya pristan
# Processing Record 9 of Set 15 | san quintin
# Processing Record 10 of Set 15 | sao luis de montes belos
# Processing Record 11 of Set 15 | phalaborwa
# Processing Record 12 of Set 15 | thinadhoo
# Processing Record 13 of Set 15 | popondetta
# Processing Record 14 of Set 15 | wanaka
# Processing Record 15 of Set 15 | great falls
# Processing Record 16 of Set 15 | staryy nadym
# Processing Record 17 of Set 15 | awash
# Processing Record 18 of Set 15 | dien bien
# City not found. Skipping...
# Processing Record 19 of Set 15 | port hardy
# Processing Record 20 of Set 15 | amaga
# Processing Record 21 of Set 15 | porto nacional
# Processing Record 22 of Set 15 | dharchula
# Processing Record 23 of Set 15 | hirara
# Processing Record 24 of Set 15 | hampton
# Processing Record 25 of Set 15 | fairbanks
# Processing Record 26 of Set 15 | mayo
# Processing Record 27 of Set 15 | homer
# Processing Record 28 of Set 15 | shache
# Processing Record 29 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 30 of Set 15 | byron bay
# Processing Record 31 of Set 15 | ponoka
# Processing Record 32 of Set 15 | quelimane
# Processing Record 33 of Set 15 | uyuni
# Processing Record 34 of Set 15 | koumac
# Processing Record 35 of Set 15 | sabzevar
# Processing Record 36 of Set 15 | forbes
# Processing Record 37 of Set 15 | srednekolymsk
# Processing Record 38 of Set 15 | samarkand
# Processing Record 39 of Set 15 | santa maria
# Processing Record 40 of Set 15 | naron
# Processing Record 41 of Set 15 | christchurch
# Processing Record 42 of Set 15 | mogadishu
# Processing Record 43 of Set 15 | kidal
# Processing Record 44 of Set 15 | margosatubig
# Processing Record 45 of Set 15 | half moon bay
# Processing Record 46 of Set 15 | marovoay
# Processing Record 47 of Set 15 | taiyuan
# Processing Record 48 of Set 15 | skibbereen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Albany',
#   'Country': 'US',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 59.29,
#   'Humidity': 27,
#   'Cloudiness': 1,
#   'Wind Speed': 3,
#   'Current Description': 'clear sky'},
#  {'City': 'Jamestown',
#   'Country': 'US',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 57.02,
#   'Humidity': 30,
#   'Cloudiness': 20,
#   'Wind Speed': 17.27,
#   'Current Description': 'few clouds'},
#  {'City': 'Lebu',
#   'Country': 'CL',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 57.9,
#   'Humidity': 70,
#   'Cloudiness': 69,
#   'Wind Speed': 7.14,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ukiah',
#   'Country': 'US',
#   'Lat': 39.1502,
#   'Lng': -123.2078,
#   'Max Temp': 41.38,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 0,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kapaa',
#   'Country': 'US',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 71.92,
#   'Humidity': 80,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Tuktoyaktuk',
#   'Country': 'CA',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': -18.4,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Current Description': 'fog'},
#  {'City': 'Qeshm',
#   'Country': 'IR',
#   'Lat': 26.9581,
#   'Lng': 56.2719,
#   'Max Temp': 98.47,
#   'Humidity': 54,
#   'Cloudiness': 100,
#   'Wind Speed': 11.74,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Alfred',
#   'Country': 'ZA',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 64.18,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Basco',
#   'Country': 'PH',
#   'Lat': 20.4487,
#   'Lng': 121.9702,
#   'Max Temp': 76.86,
#   'Humidity': 78,
#   'Cloudiness': 66,
#   'Wind Speed': 24.76,
#   'Current Description': 'broken clouds'},
#  {'City': 'Aswan',
#   'Country': 'EG',
#   'Lat': 24.0934,
#   'Lng': 32.907,
#   'Max Temp': 97.9,
#   'Humidity': 4,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Sibolga',
#   'Country': 'ID',
#   'Lat': 1.7427,
#   'Lng': 98.7792,
#   'Max Temp': 79.02,
#   'Humidity': 86,
#   'Cloudiness': 99,
#   'Wind Speed': 2.17,
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Dunedin',
#   'Country': 'NZ',
#   'Lat': -45.8742,
#   'Lng': 170.5036,
#   'Max Temp': 56.8,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Esperance',
#   'Country': 'AU',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 58.84,
#   'Humidity': 76,
#   'Cloudiness': 3,
#   'Wind Speed': 13.62,
#   'Current Description': 'clear sky'},
#  {'City': 'Puerto Ayora',
#   'Country': 'EC',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 78.76,
#   'Humidity': 81,
#   'Cloudiness': 48,
#   'Wind Speed': 10.47,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Hobart',
#   'Country': 'AU',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 55.26,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cabo San Lucas',
#   'Country': 'MX',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 72.52,
#   'Humidity': 53,
#   'Cloudiness': 100,
#   'Wind Speed': 5.64,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mahebourg',
#   'Country': 'MU',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 79.09,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Current Description': 'broken clouds'},
#  {'City': 'Tromso',
#   'Country': 'NO',
#   'Lat': 69.6496,
#   'Lng': 18.957,
#   'Max Temp': 41.02,
#   'Humidity': 60,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Current Description': 'few clouds'},
#  {'City': 'Saskylakh',
#   'Country': 'RU',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': -17.7,
#   'Humidity': 100,
#   'Cloudiness': 32,
#   'Wind Speed': 3.58,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Rikitea',
#   'Country': 'PF',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 77.61,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 14.79,
#   'Current Description': 'light rain'},
#  {'City': 'Vrangel',
#   'Country': 'RU',
#   'Lat': 42.7297,
#   'Lng': 133.0839,
#   'Max Temp': 39.27,
#   'Humidity': 73,
#   'Cloudiness': 3,
#   'Wind Speed': 5.28,
#   'Current Description': 'clear sky'},
#  {'City': 'Vardo',
#   'Country': 'NO',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp': 34.68,
#   'Humidity': 76,
#   'Cloudiness': 63,
#   'Wind Speed': 8.43,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ushuaia',
#   'Country': 'AR',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 44.22,
#   'Humidity': 81,
#   'Cloudiness': 40,
#   'Wind Speed': 2.3,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Shar',
#   'Country': 'KZ',
#   'Lat': 49.5886,
#   'Lng': 81.0453,
#   'Max Temp': 49.66,
#   'Humidity': 32,
#   'Cloudiness': 2,
#   'Wind Speed': 8.21,
#   'Current Description': 'clear sky'},
#  {'City': 'Arlit',
#   'Country': 'NE',
#   'Lat': 18.7369,
#   'Lng': 7.3853,
#   'Max Temp': 104.99,
#   'Humidity': 5,
#   'Cloudiness': 22,
#   'Wind Speed': 18.66,
#   'Current Description': 'few clouds'},
#  {'City': 'Bluff',
#   'Country': 'NZ',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 59.81,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 22.59,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Punta Arenas',
#   'Country': 'CL',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 48.31,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Current Description': 'broken clouds'},
#  {'City': 'Parana',
#   'Country': 'AR',
#   'Lat': -31.732,
#   'Lng': -60.5238,
#   'Max Temp': 69.57,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 7.78,
#   'Current Description': 'clear sky'},
#  {'City': 'Salalah',
#   'Country': 'OM',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 84.29,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Atuona',
#   'Country': 'PF',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 78.33,
#   'Humidity': 78,
#   'Cloudiness': 26,
#   'Wind Speed': 14.61,
#   'Current Description': 'light rain'},
#  {'City': 'Atar',
#   'Country': 'MR',
#   'Lat': 20.5169,
#   'Lng': -13.0499,
#   'Max Temp': 97.2,
#   'Humidity': 5,
#   'Cloudiness': 0,
#   'Wind Speed': 8.57,
#   'Current Description': 'clear sky'},
#  {'City': 'Bambous Virieux',
#   'Country': 'MU',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 79.05,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Current Description': 'light rain'},
#  {'City': 'Hermanus',
#   'Country': 'ZA',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 61.97,
#   'Humidity': 52,
#   'Cloudiness': 3,
#   'Wind Speed': 18.52,
#   'Current Description': 'clear sky'},
#  {'City': 'Dikson',
#   'Country': 'RU',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 22.6,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 15.59,
#   'Current Description': 'snow'},
#  {'City': 'Qaanaaq',
#   'Country': 'GL',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': -1.53,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 2.3,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vaini',
#   'Country': 'TO',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 77.16,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Cape Town',
#   'Country': 'ZA',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 69.12,
#   'Humidity': 48,
#   'Cloudiness': 20,
#   'Wind Speed': 23.02,
#   'Current Description': 'few clouds'},
#  {'City': 'Salekhard',
#   'Country': 'RU',
#   'Lat': 66.53,
#   'Lng': 66.6019,
#   'Max Temp': 25.07,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 11.45,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vao',
#   'Country': 'NC',
#   'Lat': -22.6667,
#   'Lng': 167.4833,
#   'Max Temp': 74.46,
#   'Humidity': 80,
#   'Cloudiness': 93,
#   'Wind Speed': 14.09,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pala',
#   'Country': 'TD',
#   'Lat': 9.3642,
#   'Lng': 14.9046,
#   'Max Temp': 100.53,
#   'Humidity': 23,
#   'Cloudiness': 100,
#   'Wind Speed': 2.46,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kodiak',
#   'Country': 'US',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 38.71,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 17.27,
#   'Current Description': 'moderate rain'},
#  {'City': 'Saint George',
#   'Country': 'US',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 54.79,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'Leshukonskoye',
#   'Country': 'RU',
#   'Lat': 64.8989,
#   'Lng': 45.7622,
#   'Max Temp': 29.01,
#   'Humidity': 79,
#   'Cloudiness': 86,
#   'Wind Speed': 7.72,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Matagami',
#   'Country': 'CA',
#   'Lat': 49.7502,
#   'Lng': -77.6328,
#   'Max Temp': 35.71,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 12.66,
#   'Current Description': 'few clouds'},
#  {'City': 'Sobolevo',
#   'Country': 'RU',
#   'Lat': 54.4299,
#   'Lng': 31.8996,
#   'Max Temp': 47.88,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 4.47,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Caetite',
#   'Country': 'BR',
#   'Lat': -14.0694,
#   'Lng': -42.475,
#   'Max Temp': 80.06,
#   'Humidity': 67,
#   'Cloudiness': 73,
#   'Wind Speed': 5.55,
#   'Current Description': 'broken clouds'},
#  {'City': 'Victoria',
#   'Country': 'HK',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 75.33,
#   'Humidity': 77,
#   'Cloudiness': 28,
#   'Wind Speed': 18.99,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Worland',
#   'Country': 'US',
#   'Lat': 44.0169,
#   'Lng': -107.9554,
#   'Max Temp': 21.67,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 10.36,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Talnakh',
#   'Country': 'RU',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': 34.21,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 11.03,
#   'Current Description': 'snow'},
#  {'City': 'Tautira',
#   'Country': 'PF',
#   'Lat': -17.7333,
#   'Lng': -149.15,
#   'Max Temp': 80.67,
#   'Humidity': 73,
#   'Cloudiness': 19,
#   'Wind Speed': 17.22,
#   'Current Description': 'few clouds'},
#  {'City': 'Yellowknife',
#   'Country': 'CA',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 11.41,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Current Description': 'broken clouds'},
#  {'City': 'Banjar',
#   'Country': 'ID',
#   'Lat': -8.19,
#   'Lng': 114.9675,
#   'Max Temp': 78.62,
#   'Humidity': 89,
#   'Cloudiness': 72,
#   'Wind Speed': 3.83,
#   'Current Description': 'broken clouds'},
#  {'City': 'Abramovka',
#   'Country': 'RU',
#   'Lat': 51.1886,
#   'Lng': 41.0202,
#   'Max Temp': 53.06,
#   'Humidity': 57,
#   'Cloudiness': 87,
#   'Wind Speed': 6.4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Rawson',
#   'Country': 'AR',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp': 73.45,
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 13.85,
#   'Current Description': 'clear sky'},
#  {'City': 'Lincoln',
#   'Country': 'US',
#   'Lat': 40.8,
#   'Lng': -96.667,
#   'Max Temp': 37.17,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 17.27,
#   'Current Description': 'clear sky'},
#  {'City': 'Hilo',
#   'Country': 'US',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 73.27,
#   'Humidity': 90,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Current Description': 'broken clouds'},
#  {'City': 'Avera',
#   'Country': 'US',
#   'Lat': 33.194,
#   'Lng': -82.5271,
#   'Max Temp': 68.56,
#   'Humidity': 34,
#   'Cloudiness': 18,
#   'Wind Speed': 15.5,
#   'Current Description': 'few clouds'},
#  {'City': 'Vidalia',
#   'Country': 'US',
#   'Lat': 32.2177,
#   'Lng': -82.4135,
#   'Max Temp': 69.91,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Current Description': 'clear sky'},
#  {'City': 'Alofi',
#   'Country': 'NU',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp': 71.49,
#   'Humidity': 100,
#   'Cloudiness': 7,
#   'Wind Speed': 1.14,
#   'Current Description': 'clear sky'},
#  {'City': 'Upernavik',
#   'Country': 'GL',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': -8.18,
#   'Humidity': 93,
#   'Cloudiness': 31,
#   'Wind Speed': 12.73,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Pasighat',
#   'Country': 'IN',
#   'Lat': 28.0667,
#   'Lng': 95.3333,
#   'Max Temp': 67.95,
#   'Humidity': 91,
#   'Cloudiness': 80,
#   'Wind Speed': 6.46,
#   'Current Description': 'broken clouds'},
#  {'City': 'Tiksi',
#   'Country': 'RU',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': -3.98,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 5.57,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Butaritari',
#   'Country': 'KI',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 80.44,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 3.65,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Osmena',
#   'Country': 'PH',
#   'Lat': 10.5208,
#   'Lng': 119.9258,
#   'Max Temp': 81.03,
#   'Humidity': 77,
#   'Cloudiness': 46,
#   'Wind Speed': 4.14,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bandarbeyla',
#   'Country': 'SO',
#   'Lat': 9.4942,
#   'Lng': 50.8122,
#   'Max Temp': 83.52,
#   'Humidity': 79,
#   'Cloudiness': 70,
#   'Wind Speed': 13.02,
#   'Current Description': 'broken clouds'},
#  {'City': 'Komsomolskiy',
#   'Country': 'UZ',
#   'Lat': 40.4272,
#   'Lng': 71.7189,
#   'Max Temp': 75.92,
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Sao Gabriel Da Cachoeira',
#   'Country': 'BR',
#   'Lat': -0.1303,
#   'Lng': -67.0892,
#   'Max Temp': 73.44,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 1.5,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Avarua',
#   'Country': 'CK',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 77.05,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Current Description': 'few clouds'},
#  {'City': 'Requena',
#   'Country': 'ES',
#   'Lat': 39.4883,
#   'Lng': -1.1004,
#   'Max Temp': 66.52,
#   'Humidity': 40,
#   'Cloudiness': 16,
#   'Wind Speed': 9.31,
#   'Current Description': 'few clouds'},
#  {'City': 'Eirunepe',
#   'Country': 'BR',
#   'Lat': -6.6603,
#   'Lng': -69.8736,
#   'Max Temp': 76.8,
#   'Humidity': 87,
#   'Cloudiness': 99,
#   'Wind Speed': 1.79,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ganzhou',
#   'Country': 'CN',
#   'Lat': 28.8184,
#   'Lng': 115.4327,
#   'Max Temp': 54.09,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 8.21,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Georgetown',
#   'Country': 'MY',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 84.15,
#   'Humidity': 80,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Current Description': 'few clouds'},
#  {'City': 'Alice Springs',
#   'Country': 'AU',
#   'Lat': -23.7,
#   'Lng': 133.8833,
#   'Max Temp': 74.75,
#   'Humidity': 33,
#   'Cloudiness': 4,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Christiansburg',
#   'Country': 'US',
#   'Lat': 37.1298,
#   'Lng': -80.4089,
#   'Max Temp': 59.76,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'Barrow',
#   'Country': 'US',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': -5.78,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 21.85,
#   'Current Description': 'clear sky'},
#  {'City': 'Mataura',
#   'Country': 'NZ',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 59.49,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 11.34,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bud',
#   'Country': 'US',
#   'Lat': 39.447,
#   'Lng': -86.1758,
#   'Max Temp': 61.41,
#   'Humidity': 43,
#   'Cloudiness': 19,
#   'Wind Speed': 16.17,
#   'Current Description': 'few clouds'},
#  {'City': 'Rocha',
#   'Country': 'UY',
#   'Lat': -34.4833,
#   'Lng': -54.3333,
#   'Max Temp': 67.64,
#   'Humidity': 60,
#   'Cloudiness': 90,
#   'Wind Speed': 9.22,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kachiry',
#   'Country': 'KZ',
#   'Lat': 53.0675,
#   'Lng': 76.1036,
#   'Max Temp': 58.6,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 9.08,
#   'Current Description': 'clear sky'},
#  {'City': 'Sitka',
#   'Country': 'US',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 30.09,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'Bethel',
#   'Country': 'US',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 62.46,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Current Description': 'clear sky'},
#  {'City': 'Vasto',
#   'Country': 'IT',
#   'Lat': 42.1243,
#   'Lng': 14.7059,
#   'Max Temp': 64.69,
#   'Humidity': 59,
#   'Cloudiness': 98,
#   'Wind Speed': 5.26,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Shevchenkove',
#   'Country': 'UA',
#   'Lat': 49.6959,
#   'Lng': 37.1735,
#   'Max Temp': 59.07,
#   'Humidity': 52,
#   'Cloudiness': 76,
#   'Wind Speed': 7.05,
#   'Current Description': 'broken clouds'},
#  {'City': 'Dingle',
#   'Country': 'PH',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 76.57,
#   'Humidity': 91,
#   'Cloudiness': 72,
#   'Wind Speed': 1.28,
#   'Current Description': 'broken clouds'},
#  {'City': 'Ullapool',
#   'Country': 'GB',
#   'Lat': 57.8987,
#   'Lng': -5.1604,
#   'Max Temp': 59.34,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 0.74,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Montepuez',
#   'Country': 'MZ',
#   'Lat': -13.1256,
#   'Lng': 38.9997,
#   'Max Temp': 74.66,
#   'Humidity': 88,
#   'Cloudiness': 15,
#   'Wind Speed': 6.17,
#   'Current Description': 'few clouds'},
#  {'City': 'Busselton',
#   'Country': 'AU',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 58.96,
#   'Humidity': 91,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Thompson',
#   'Country': 'CA',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 8.76,
#   'Humidity': 52,
#   'Cloudiness': 75,
#   'Wind Speed': 17.27,
#   'Current Description': 'broken clouds'},
#  {'City': 'Nome',
#   'Country': 'US',
#   'Lat': 64.5011,
#   'Lng': -165.4064,
#   'Max Temp': 37.47,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 25.32,
#   'Current Description': 'overcast clouds'},
#  {'City': 'El Rincon',
#   'Country': 'HN',
#   'Lat': 14.5833,
#   'Lng': -87.9333,
#   'Max Temp': 69.64,
#   'Humidity': 47,
#   'Cloudiness': 64,
#   'Wind Speed': 2.64,
#   'Current Description': 'broken clouds'},
#  {'City': 'Sioux Lookout',
#   'Country': 'CA',
#   'Lat': 50.1001,
#   'Lng': -91.917,
#   'Max Temp': 14.07,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Airai',
#   'Country': 'TL',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 62.28,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 2.44,
#   'Current Description': 'light rain'},
#  {'City': 'Obo',
#   'Country': 'CF',
#   'Lat': 5.3998,
#   'Lng': 26.4869,
#   'Max Temp': 77.63,
#   'Humidity': 67,
#   'Cloudiness': 77,
#   'Wind Speed': 8.81,
#   'Current Description': 'broken clouds'},
#  {'City': 'Sorland',
#   'Country': 'NO',
#   'Lat': 67.667,
#   'Lng': 12.6934,
#   'Max Temp': 38.32,
#   'Humidity': 68,
#   'Cloudiness': 99,
#   'Wind Speed': 8.5,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kijang',
#   'Country': 'KR',
#   'Lat': 35.2442,
#   'Lng': 129.2139,
#   'Max Temp': 51.53,
#   'Humidity': 59,
#   'Cloudiness': 72,
#   'Wind Speed': 10.56,
#   'Current Description': 'broken clouds'},
#  {'City': 'Muzaffarpur',
#   'Country': 'IN',
#   'Lat': 26.1167,
#   'Lng': 85.4,
#   'Max Temp': 91.85,
#   'Humidity': 11,
#   'Cloudiness': 21,
#   'Wind Speed': 7.47,
#   'Current Description': 'few clouds'},
#  {'City': 'Yarada',
#   'Country': 'IN',
#   'Lat': 17.65,
#   'Lng': 83.2667,
#   'Max Temp': 86.32,
#   'Humidity': 79,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Current Description': 'broken clouds'},
#  {'City': 'Olafsvik',
#   'Country': 'IS',
#   'Lat': 64.8945,
#   'Lng': -23.7142,
#   'Max Temp': 44.71,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 24.02,
#   'Current Description': 'light rain'},
#  {'City': 'Sao Joao Da Barra',
#   'Country': 'BR',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 78.89,
#   'Humidity': 58,
#   'Cloudiness': 99,
#   'Wind Speed': 23.58,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Qasigiannguit',
#   'Country': 'GL',
#   'Lat': 68.8193,
#   'Lng': -51.1922,
#   'Max Temp': -0.24,
#   'Humidity': 84,
#   'Cloudiness': 40,
#   'Wind Speed': 1.77,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Provideniya',
#   'Country': 'RU',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 30.16,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 17.43,
#   'Current Description': 'snow'},
#  {'City': 'Tabuk',
#   'Country': 'PH',
#   'Lat': 17.4189,
#   'Lng': 121.4443,
#   'Max Temp': 74.3,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 7.09,
#   'Current Description': 'overcast clouds'},
#  {'City': 'East London',
#   'Country': 'ZA',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 59.94,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 18.41,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bredasdorp',
#   'Country': 'ZA',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 60.64,
#   'Humidity': 47,
#   'Cloudiness': 35,
#   'Wind Speed': 13.47,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Tasiilaq',
#   'Country': 'GL',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 33.93,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 10.96,
#   'Current Description': 'snow'},
#  {'City': 'Ixtapa',
#   'Country': 'MX',
#   'Lat': 20.7,
#   'Lng': -105.2,
#   'Max Temp': 81.32,
#   'Humidity': 28,
#   'Cloudiness': 98,
#   'Wind Speed': 2.82,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hede',
#   'Country': 'CN',
#   'Lat': 33.7681,
#   'Lng': 120.2517,
#   'Max Temp': 50.05,
#   'Humidity': 59,
#   'Cloudiness': 100,
#   'Wind Speed': 9.28,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kahului',
#   'Country': 'US',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 72.84,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Torbay',
#   'Country': 'CA',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 41.88,
#   'Humidity': 64,
#   'Cloudiness': 40,
#   'Wind Speed': 6.91,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bogovarovo',
#   'Country': 'RU',
#   'Lat': 58.9785,
#   'Lng': 47.0246,
#   'Max Temp': 32.49,
#   'Humidity': 80,
#   'Cloudiness': 93,
#   'Wind Speed': 10.33,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Alyangula',
#   'Country': 'AU',
#   'Lat': -13.8483,
#   'Lng': 136.4192,
#   'Max Temp': 76.87,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Current Description': 'moderate rain'},
#  {'City': 'Smithers',
#   'Country': 'CA',
#   'Lat': 54.7804,
#   'Lng': -127.1743,
#   'Max Temp': 17.92,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Current Description': 'clear sky'},
#  {'City': 'Port Elizabeth',
#   'Country': 'ZA',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 64.69,
#   'Humidity': 58,
#   'Cloudiness': 20,
#   'Wind Speed': 12.66,
#   'Current Description': 'few clouds'},
#  {'City': 'Murray Bridge',
#   'Country': 'AU',
#   'Lat': -35.1167,
#   'Lng': 139.2667,
#   'Max Temp': 61.34,
#   'Humidity': 95,
#   'Cloudiness': 7,
#   'Wind Speed': 1.63,
#   'Current Description': 'clear sky'},
#  {'City': 'Harper',
#   'Country': 'LR',
#   'Lat': 4.375,
#   'Lng': -7.7169,
#   'Max Temp': 83.37,
#   'Humidity': 70,
#   'Cloudiness': 98,
#   'Wind Speed': 8.81,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Omaha',
#   'Country': 'US',
#   'Lat': 41.2586,
#   'Lng': -95.9378,
#   'Max Temp': 36.16,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Current Description': 'clear sky'},
#  {'City': 'Cidreira',
#   'Country': 'BR',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 63,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 7.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bengkulu',
#   'Country': 'ID',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 78.42,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 3.62,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ponta Delgada',
#   'Country': 'PT',
#   'Lat': 37.7333,
#   'Lng': -25.6667,
#   'Max Temp': 61.52,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Current Description': 'broken clouds'},
#  {'City': 'Hambantota',
#   'Country': 'LK',
#   'Lat': 6.1241,
#   'Lng': 81.1185,
#   'Max Temp': 82.74,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Vaitape',
#   'Country': 'PF',
#   'Lat': -16.5167,
#   'Lng': -151.75,
#   'Max Temp': 81.34,
#   'Humidity': 72,
#   'Cloudiness': 7,
#   'Wind Speed': 15.64,
#   'Current Description': 'light rain'},
#  {'City': 'Tabas',
#   'Country': 'IR',
#   'Lat': 33.5959,
#   'Lng': 56.9244,
#   'Max Temp': 87.4,
#   'Humidity': 12,
#   'Cloudiness': 100,
#   'Wind Speed': 5.35,
#   'Current Description': 'overcast clouds'},
#  {'City': 'San Jose',
#   'Country': 'US',
#   'Lat': 37.3394,
#   'Lng': -121.895,
#   'Max Temp': 53.51,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kabalo',
#   'Country': 'CD',
#   'Lat': -6.05,
#   'Lng': 26.9167,
#   'Max Temp': 75.51,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 5.35,
#   'Current Description': 'moderate rain'},
#  {'City': 'Lowestoft',
#   'Country': 'GB',
#   'Lat': 52.4752,
#   'Lng': 1.7516,
#   'Max Temp': 64.08,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 8.79,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kismayo',
#   'Country': 'SO',
#   'Lat': -0.3582,
#   'Lng': 42.5454,
#   'Max Temp': 84.43,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 11.1,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dauphin',
#   'Country': 'CA',
#   'Lat': 51.1494,
#   'Lng': -100.0502,
#   'Max Temp': 14.14,
#   'Humidity': 67,
#   'Cloudiness': 20,
#   'Wind Speed': 14.97,
#   'Current Description': 'few clouds'},
#  {'City': 'Sola',
#   'Country': 'VU',
#   'Lat': -13.8833,
#   'Lng': 167.55,
#   'Max Temp': 81.57,
#   'Humidity': 70,
#   'Cloudiness': 81,
#   'Wind Speed': 1.7,
#   'Current Description': 'broken clouds'},
#  {'City': 'Sao Jose Da Coroa Grande',
#   'Country': 'BR',
#   'Lat': -8.8978,
#   'Lng': -35.1478,
#   'Max Temp': 85.23,
#   'Humidity': 63,
#   'Cloudiness': 71,
#   'Wind Speed': 10.71,
#   'Current Description': 'broken clouds'},
#  {'City': 'Mokhsogollokh',
#   'Country': 'RU',
#   'Lat': 61.4681,
#   'Lng': 128.9203,
#   'Max Temp': 25.36,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 3.94,
#   'Current Description': 'light snow'},
#  {'City': 'Pingliang',
#   'Country': 'CN',
#   'Lat': 35.5392,
#   'Lng': 106.6861,
#   'Max Temp': 38.97,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 7.02,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Asau',
#   'Country': 'RO',
#   'Lat': 46.4333,
#   'Lng': 26.4,
#   'Max Temp': 69.28,
#   'Humidity': 34,
#   'Cloudiness': 1,
#   'Wind Speed': 8.46,
#   'Current Description': 'clear sky'},
#  {'City': 'Vila Velha',
#   'Country': 'BR',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 80.55,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 20,
#   'Current Description': 'broken clouds'},
#  {'City': 'Grand Gaube',
#   'Country': 'MU',
#   'Lat': -20.0064,
#   'Lng': 57.6608,
#   'Max Temp': 79.2,
#   'Humidity': 83,
#   'Cloudiness': 4,
#   'Wind Speed': 7,
#   'Current Description': 'clear sky'},
#  {'City': 'Katobu',
#   'Country': 'ID',
#   'Lat': -4.9408,
#   'Lng': 122.5276,
#   'Max Temp': 76.12,
#   'Humidity': 94,
#   'Cloudiness': 41,
#   'Wind Speed': 3.65,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Manacapuru',
#   'Country': 'BR',
#   'Lat': -3.2997,
#   'Lng': -60.6206,
#   'Max Temp': 80.35,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 2.73,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Urumqi',
#   'Country': 'CN',
#   'Lat': 43.801,
#   'Lng': 87.6005,
#   'Max Temp': 43.75,
#   'Humidity': 13,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Current Description': 'clear sky'},
#  {'City': 'Itacare',
#   'Country': 'BR',
#   'Lat': -14.2775,
#   'Lng': -38.9967,
#   'Max Temp': 87.48,
#   'Humidity': 62,
#   'Cloudiness': 11,
#   'Wind Speed': 12.91,
#   'Current Description': 'few clouds'},
#  {'City': 'Montorio Al Vomano',
#   'Country': 'IT',
#   'Lat': 42.5831,
#   'Lng': 13.6383,
#   'Max Temp': 76.44,
#   'Humidity': 60,
#   'Cloudiness': 89,
#   'Wind Speed': 5.55,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Rio Gallegos',
#   'Country': 'AR',
#   'Lat': -51.6226,
#   'Lng': -69.2181,
#   'Max Temp': 46.45,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Current Description': 'moderate rain'},
#  {'City': 'Santa Rosa',
#   'Country': 'PH',
#   'Lat': 14.3122,
#   'Lng': 121.1114,
#   'Max Temp': 83.1,
#   'Humidity': 81,
#   'Cloudiness': 74,
#   'Wind Speed': 4.38,
#   'Current Description': 'broken clouds'},
#  {'City': 'Grand Baie',
#   'Country': 'MU',
#   'Lat': -20.0182,
#   'Lng': 57.5802,
#   'Max Temp': 79.27,
#   'Humidity': 83,
#   'Cloudiness': 4,
#   'Wind Speed': 7,
#   'Current Description': 'clear sky'},
#  {'City': 'Husavik',
#   'Country': 'IS',
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Max Temp': 48.54,
#   'Humidity': 66,
#   'Cloudiness': 99,
#   'Wind Speed': 14.25,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tay Ninh',
#   'Country': 'VN',
#   'Lat': 11.3,
#   'Lng': 106.1,
#   'Max Temp': 82.74,
#   'Humidity': 74,
#   'Cloudiness': 98,
#   'Wind Speed': 6.38,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Klaksvik',
#   'Country': 'FO',
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Max Temp': 49.12,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 14.58,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Yerbogachen',
#   'Country': 'RU',
#   'Lat': 61.2767,
#   'Lng': 108.0108,
#   'Max Temp': 13.89,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 1.23,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nikolskoye',
#   'Country': 'RU',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 42.69,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 7.94,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lingyuan',
#   'Country': 'CN',
#   'Lat': 41.24,
#   'Lng': 119.4011,
#   'Max Temp': 47.3,
#   'Humidity': 19,
#   'Cloudiness': 0,
#   'Wind Speed': 5.3,
#   'Current Description': 'clear sky'},
#  {'City': 'Kerouane',
#   'Country': 'GN',
#   'Lat': 9.2667,
#   'Lng': -9.0167,
#   'Max Temp': 95.36,
#   'Humidity': 32,
#   'Cloudiness': 52,
#   'Wind Speed': 5.48,
#   'Current Description': 'broken clouds'},
#  {'City': 'Evensk',
#   'Country': 'RU',
#   'Lat': 61.95,
#   'Lng': 159.2333,
#   'Max Temp': 23.83,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Current Description': 'light snow'},
#  {'City': 'Biabou',
#   'Country': 'VC',
#   'Lat': 13.2,
#   'Lng': -61.1333,
#   'Max Temp': 82.4,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Current Description': 'broken clouds'},
#  {'City': 'New Norfolk',
#   'Country': 'AU',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 54.9,
#   'Humidity': 73,
#   'Cloudiness': 55,
#   'Wind Speed': 1.97,
#   'Current Description': 'broken clouds'},
#  {'City': 'Haimen',
#   'Country': 'CN',
#   'Lat': 23.1935,
#   'Lng': 116.6142,
#   'Max Temp': 67.89,
#   'Humidity': 77,
#   'Cloudiness': 34,
#   'Wind Speed': 27,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kuusamo',
#   'Country': 'FI',
#   'Lat': 65.9667,
#   'Lng': 29.1833,
#   'Max Temp': 37.44,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Current Description': 'clear sky'},
#  {'City': 'Egvekinot',
#   'Country': 'RU',
#   'Lat': 66.3167,
#   'Lng': -179.1667,
#   'Max Temp': 19.51,
#   'Humidity': 86,
#   'Cloudiness': 93,
#   'Wind Speed': 20.11,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Yulara',
#   'Country': 'AU',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 85.84,
#   'Humidity': 26,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Majene',
#   'Country': 'ID',
#   'Lat': -3.5403,
#   'Lng': 118.9707,
#   'Max Temp': 79.75,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 1.5,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kyabe',
#   'Country': 'TD',
#   'Lat': 9.4515,
#   'Lng': 18.9449,
#   'Max Temp': 102.52,
#   'Humidity': 19,
#   'Cloudiness': 73,
#   'Wind Speed': 1.81,
#   'Current Description': 'broken clouds'},
#  {'City': 'Altagracia De Orituco',
#   'Country': 'VE',
#   'Lat': 9.8601,
#   'Lng': -66.3814,
#   'Max Temp': 88.09,
#   'Humidity': 42,
#   'Cloudiness': 73,
#   'Wind Speed': 7.58,
#   'Current Description': 'broken clouds'},
#  {'City': 'Nshamba',
#   'Country': 'TZ',
#   'Lat': -1.7983,
#   'Lng': 31.5511,
#   'Max Temp': 69.51,
#   'Humidity': 81,
#   'Cloudiness': 99,
#   'Wind Speed': 5.17,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Taoudenni',
#   'Country': 'ML',
#   'Lat': 22.6783,
#   'Lng': -3.9836,
#   'Max Temp': 93.54,
#   'Humidity': 7,
#   'Cloudiness': 0,
#   'Wind Speed': 13.78,
#   'Current Description': 'clear sky'},
#  {'City': 'Havoysund',
#   'Country': 'NO',
#   'Lat': 70.9963,
#   'Lng': 24.6622,
#   'Max Temp': 37.63,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 24.74,
#   'Current Description': 'light rain'},
#  {'City': 'Boyolangu',
#   'Country': 'ID',
#   'Lat': -8.1181,
#   'Lng': 111.8935,
#   'Max Temp': 76.42,
#   'Humidity': 92,
#   'Cloudiness': 80,
#   'Wind Speed': 0.72,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kapit',
#   'Country': 'MY',
#   'Lat': 2.0167,
#   'Lng': 112.9333,
#   'Max Temp': 75.87,
#   'Humidity': 93,
#   'Cloudiness': 99,
#   'Wind Speed': 0.69,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Astoria',
#   'Country': 'US',
#   'Lat': 46.1879,
#   'Lng': -123.8313,
#   'Max Temp': 38.86,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chokurdakh',
#   'Country': 'RU',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': 10.4,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Current Description': 'light snow'},
#  {'City': 'Lorengau',
#   'Country': 'PG',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 81.97,
#   'Humidity': 78,
#   'Cloudiness': 43,
#   'Wind Speed': 6.24,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Tobermory',
#   'Country': 'CA',
#   'Lat': 45.2501,
#   'Lng': -81.6665,
#   'Max Temp': 36.23,
#   'Humidity': 63,
#   'Cloudiness': 97,
#   'Wind Speed': 23.22,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kaitangata',
#   'Country': 'NZ',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 52.34,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 7.54,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dryden',
#   'Country': 'CA',
#   'Lat': 49.7833,
#   'Lng': -92.7503,
#   'Max Temp': 16.09,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 10.36,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chokwe',
#   'Country': 'MZ',
#   'Lat': -24.5333,
#   'Lng': 32.9833,
#   'Max Temp': 93.56,
#   'Humidity': 38,
#   'Cloudiness': 39,
#   'Wind Speed': 2.37,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Khatanga',
#   'Country': 'RU',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 12.09,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 13.2,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Faya',
#   'Country': 'SA',
#   'Lat': 18.3851,
#   'Lng': 42.4509,
#   'Max Temp': 79.32,
#   'Humidity': 33,
#   'Cloudiness': 4,
#   'Wind Speed': 9.82,
#   'Current Description': 'clear sky'},
#  {'City': 'Ambon',
#   'Country': 'ID',
#   'Lat': -3.6954,
#   'Lng': 128.1814,
#   'Max Temp': 78.94,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Current Description': 'few clouds'},
#  {'City': 'Qaqortoq',
#   'Country': 'GL',
#   'Lat': 60.7167,
#   'Lng': -46.0333,
#   'Max Temp': 28.26,
#   'Humidity': 65,
#   'Cloudiness': 66,
#   'Wind Speed': 8.25,
#   'Current Description': 'broken clouds'},
#  {'City': 'Sigayevo',
#   'Country': 'RU',
#   'Lat': 56.4216,
#   'Lng': 53.7757,
#   'Max Temp': 39.92,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 2.73,
#   'Current Description': 'light rain'},
#  {'City': 'Laramie',
#   'Country': 'US',
#   'Lat': 41.3114,
#   'Lng': -105.5911,
#   'Max Temp': 44.53,
#   'Humidity': 55,
#   'Cloudiness': 99,
#   'Wind Speed': 5.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Intipuca',
#   'Country': 'SV',
#   'Lat': 13.1969,
#   'Lng': -88.0544,
#   'Max Temp': 91.15,
#   'Humidity': 45,
#   'Cloudiness': 33,
#   'Wind Speed': 1.36,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Chapais',
#   'Country': 'CA',
#   'Lat': 49.7834,
#   'Lng': -74.8492,
#   'Max Temp': 35.38,
#   'Humidity': 65,
#   'Cloudiness': 84,
#   'Wind Speed': 13.22,
#   'Current Description': 'broken clouds'},
#  {'City': 'Penha',
#   'Country': 'BR',
#   'Lat': -26.7694,
#   'Lng': -48.6458,
#   'Max Temp': 67.87,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Current Description': 'clear sky'},
#  {'City': 'Ahmadpur East',
#   'Country': 'PK',
#   'Lat': 29.1431,
#   'Lng': 71.2598,
#   'Max Temp': 93.79,
#   'Humidity': 8,
#   'Cloudiness': 0,
#   'Wind Speed': 3,
#   'Current Description': 'clear sky'},
#  {'City': 'Wanning',
#   'Country': 'CN',
#   'Lat': 18.8003,
#   'Lng': 110.3967,
#   'Max Temp': 76.03,
#   'Humidity': 92,
#   'Cloudiness': 2,
#   'Wind Speed': 5.3,
#   'Current Description': 'clear sky'},
#  {'City': 'Carnarvon',
#   'Country': 'AU',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 77.07,
#   'Humidity': 69,
#   'Cloudiness': 51,
#   'Wind Speed': 12.66,
#   'Current Description': 'broken clouds'},
#  {'City': 'Arraial Do Cabo',
#   'Country': 'BR',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 76.86,
#   'Humidity': 53,
#   'Cloudiness': 75,
#   'Wind Speed': 18.41,
#   'Current Description': 'broken clouds'},
#  {'City': 'Tigil',
#   'Country': 'RU',
#   'Lat': 57.8,
#   'Lng': 158.6667,
#   'Max Temp': 23.49,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 12.39,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Erenhot',
#   'Country': 'CN',
#   'Lat': 43.6475,
#   'Lng': 111.9767,
#   'Max Temp': 44.31,
#   'Humidity': 16,
#   'Cloudiness': 61,
#   'Wind Speed': 5.86,
#   'Current Description': 'broken clouds'},
#  {'City': 'Verkhnevilyuysk',
#   'Country': 'RU',
#   'Lat': 63.4453,
#   'Lng': 120.3167,
#   'Max Temp': 25.43,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hithadhoo',
#   'Country': 'MV',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 84.02,
#   'Humidity': 65,
#   'Cloudiness': 10,
#   'Wind Speed': 3.04,
#   'Current Description': 'clear sky'},
#  {'City': 'Coquimbo',
#   'Country': 'CL',
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp': 58.73,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Current Description': 'overcast clouds'},
#  {'City': 'La Romana',
#   'Country': 'DO',
#   'Lat': 18.4273,
#   'Lng': -68.9728,
#   'Max Temp': 82.76,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Touros',
#   'Country': 'BR',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 87.98,
#   'Humidity': 59,
#   'Cloudiness': 58,
#   'Wind Speed': 10.65,
#   'Current Description': 'broken clouds'},
#  {'City': 'Lagoa',
#   'Country': 'PT',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 58.77,
#   'Humidity': 78,
#   'Cloudiness': 72,
#   'Wind Speed': 20.42,
#   'Current Description': 'broken clouds'},
#  {'City': 'Valparaiso',
#   'Country': 'CL',
#   'Lat': -33.0393,
#   'Lng': -71.6273,
#   'Max Temp': 58.64,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Manokwari',
#   'Country': 'ID',
#   'Lat': -0.8667,
#   'Lng': 134.0833,
#   'Max Temp': 79.38,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 2.37,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Laguna',
#   'Country': 'US',
#   'Lat': 38.421,
#   'Lng': -121.4238,
#   'Max Temp': 53.62,
#   'Humidity': 81,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Current Description': 'few clouds'},
#  {'City': 'Aguai',
#   'Country': 'BR',
#   'Lat': -22.0594,
#   'Lng': -46.9786,
#   'Max Temp': 70.9,
#   'Humidity': 57,
#   'Cloudiness': 21,
#   'Wind Speed': 8.03,
#   'Current Description': 'few clouds'},
#  {'City': 'Kudahuvadhoo',
#   'Country': 'MV',
#   'Lat': 2.6708,
#   'Lng': 72.8944,
#   'Max Temp': 84.87,
#   'Humidity': 67,
#   'Cloudiness': 22,
#   'Wind Speed': 3.85,
#   'Current Description': 'few clouds'},
#  {'City': 'Saint-Philippe',
#   'Country': 'RE',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 78.39,
#   'Humidity': 83,
#   'Cloudiness': 57,
#   'Wind Speed': 15.61,
#   'Current Description': 'light rain'},
#  {'City': 'Conceicao Do Araguaia',
#   'Country': 'BR',
#   'Lat': -8.2578,
#   'Lng': -49.2647,
#   'Max Temp': 84.29,
#   'Humidity': 71,
#   'Cloudiness': 82,
#   'Wind Speed': 4.83,
#   'Current Description': 'broken clouds'},
#  {'City': 'Rapid Valley',
#   'Country': 'US',
#   'Lat': 44.0625,
#   'Lng': -103.1463,
#   'Max Temp': 22.77,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 18.41,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Haines Junction',
#   'Country': 'CA',
#   'Lat': 60.7522,
#   'Lng': -137.5108,
#   'Max Temp': 10.35,
#   'Humidity': 79,
#   'Cloudiness': 15,
#   'Wind Speed': 0,
#   'Current Description': 'few clouds'},
#  {'City': 'Awjilah',
#   'Country': 'LY',
#   'Lat': 29.1081,
#   'Lng': 21.2869,
#   'Max Temp': 98.06,
#   'Humidity': 7,
#   'Cloudiness': 100,
#   'Wind Speed': 19.84,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Teya',
#   'Country': 'RU',
#   'Lat': 60.3778,
#   'Lng': 92.6267,
#   'Max Temp': 34.79,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 3.53,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Santa Cruz',
#   'Country': 'BO',
#   'Lat': -17.8,
#   'Lng': -63.1667,
#   'Max Temp': 73.45,
#   'Humidity': 49,
#   'Cloudiness': 20,
#   'Wind Speed': 12.66,
#   'Current Description': 'few clouds'},
#  {'City': 'Makakilo City',
#   'Country': 'US',
#   'Lat': 21.3469,
#   'Lng': -158.0858,
#   'Max Temp': 71.69,
#   'Humidity': 71,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Current Description': 'few clouds'},
#  {'City': 'Severo-Kurilsk',
#   'Country': 'RU',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 25.2,
#   'Humidity': 76,
#   'Cloudiness': 19,
#   'Wind Speed': 5.61,
#   'Current Description': 'few clouds'},
#  {'City': 'Mar Del Plata',
#   'Country': 'AR',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 60.82,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 13,
#   'Current Description': 'clear sky'},
#  {'City': 'San Cristobal',
#   'Country': 'VE',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 75.38,
#   'Humidity': 57,
#   'Cloudiness': 84,
#   'Wind Speed': 7.92,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kavieng',
#   'Country': 'PG',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 82.15,
#   'Humidity': 78,
#   'Cloudiness': 52,
#   'Wind Speed': 9.75,
#   'Current Description': 'light rain'},
#  {'City': 'Cockburn Town',
#   'Country': 'TC',
#   'Lat': 21.4612,
#   'Lng': -71.1419,
#   'Max Temp': 78.76,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 20.71,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Antofagasta',
#   'Country': 'CL',
#   'Lat': -23.65,
#   'Lng': -70.4,
#   'Max Temp': 63.68,
#   'Humidity': 63,
#   'Cloudiness': 2,
#   'Wind Speed': 9.55,
#   'Current Description': 'clear sky'},
#  {'City': 'Road Town',
#   'Country': 'VG',
#   'Lat': 18.4167,
#   'Lng': -64.6167,
#   'Max Temp': 82.44,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Heinola',
#   'Country': 'FI',
#   'Lat': 61.2056,
#   'Lng': 26.0381,
#   'Max Temp': 44.02,
#   'Humidity': 67,
#   'Cloudiness': 72,
#   'Wind Speed': 10.25,
#   'Current Description': 'broken clouds'},
#  {'City': 'Rio Grande',
#   'Country': 'BR',
#   'Lat': -32.035,
#   'Lng': -52.0986,
#   'Max Temp': 69.91,
#   'Humidity': 63,
#   'Cloudiness': 76,
#   'Wind Speed': 13.69,
#   'Current Description': 'broken clouds'},
#  {'City': 'Auki',
#   'Country': 'SB',
#   'Lat': -8.7676,
#   'Lng': 160.7034,
#   'Max Temp': 77.13,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 0.98,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kruisfontein',
#   'Country': 'ZA',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 60.89,
#   'Humidity': 53,
#   'Cloudiness': 100,
#   'Wind Speed': 8.03,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Poninka',
#   'Country': 'UA',
#   'Lat': 50.1849,
#   'Lng': 27.5363,
#   'Max Temp': 60.19,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 15.05,
#   'Current Description': 'light rain'},
#  {'City': 'Iqaluit',
#   'Country': 'CA',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 2.93,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 16.11,
#   'Current Description': 'few clouds'},
#  {'City': 'Prince Rupert',
#   'Country': 'CA',
#   'Lat': 54.3161,
#   'Lng': -130.3201,
#   'Max Temp': 38.89,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Pisco',
#   'Country': 'PE',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 68.05,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Kandrian',
#   'Country': 'PG',
#   'Lat': -6.2167,
#   'Lng': 149.55,
#   'Max Temp': 77.47,
#   'Humidity': 90,
#   'Cloudiness': 87,
#   'Wind Speed': 4.79,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Teknaf',
#   'Country': 'BD',
#   'Lat': 20.8624,
#   'Lng': 92.3058,
#   'Max Temp': 80.82,
#   'Humidity': 88,
#   'Cloudiness': 13,
#   'Wind Speed': 5.28,
#   'Current Description': 'few clouds'},
#  {'City': 'Ulundi',
#   'Country': 'ZA',
#   'Lat': -28.3352,
#   'Lng': 31.4162,
#   'Max Temp': 69.15,
#   'Humidity': 86,
#   'Cloudiness': 14,
#   'Wind Speed': 12.08,
#   'Current Description': 'light rain'},
#  {'City': 'Myanaung',
#   'Country': 'MM',
#   'Lat': 18.2833,
#   'Lng': 95.3167,
#   'Max Temp': 88.02,
#   'Humidity': 54,
#   'Cloudiness': 7,
#   'Wind Speed': 3.69,
#   'Current Description': 'clear sky'},
#  {'City': 'Kalabo',
#   'Country': 'ZM',
#   'Lat': -14.97,
#   'Lng': 22.6814,
#   'Max Temp': 83.23,
#   'Humidity': 51,
#   'Cloudiness': 78,
#   'Wind Speed': 2.55,
#   'Current Description': 'broken clouds'},
#  {'City': 'Batagay',
#   'Country': 'RU',
#   'Lat': 67.6333,
#   'Lng': 134.6333,
#   'Max Temp': 1.72,
#   'Humidity': 100,
#   'Cloudiness': 88,
#   'Wind Speed': 1.43,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Maceio',
#   'Country': 'BR',
#   'Lat': -9.6658,
#   'Lng': -35.7353,
#   'Max Temp': 89.04,
#   'Humidity': 55,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Current Description': 'broken clouds'},
#  {'City': 'Berlevag',
#   'Country': 'NO',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 33.6,
#   'Humidity': 89,
#   'Cloudiness': 81,
#   'Wind Speed': 11.68,
#   'Current Description': 'broken clouds'},
#  {'City': 'Sorong',
#   'Country': 'ID',
#   'Lat': -0.8833,
#   'Lng': 131.25,
#   'Max Temp': 81.43,
#   'Humidity': 80,
#   'Cloudiness': 77,
#   'Wind Speed': 9.04,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kununurra',
#   'Country': 'AU',
#   'Lat': -15.7667,
#   'Lng': 128.7333,
#   'Max Temp': 78.78,
#   'Humidity': 94,
#   'Cloudiness': 68,
#   'Wind Speed': 0,
#   'Current Description': 'broken clouds'},
#  {'City': 'Sao Filipe',
#   'Country': 'CV',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 71.91,
#   'Humidity': 75,
#   'Cloudiness': 1,
#   'Wind Speed': 9.44,
#   'Current Description': 'clear sky'},
#  {'City': 'Yemtsa',
#   'Country': 'RU',
#   'Lat': 63.0734,
#   'Lng': 40.3329,
#   'Max Temp': 32.83,
#   'Humidity': 74,
#   'Cloudiness': 94,
#   'Wind Speed': 7.07,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Montespertoli',
#   'Country': 'IT',
#   'Lat': 43.6442,
#   'Lng': 11.0737,
#   'Max Temp': 79.84,
#   'Humidity': 24,
#   'Cloudiness': 5,
#   'Wind Speed': 5.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Kibaya',
#   'Country': 'TZ',
#   'Lat': -5.3,
#   'Lng': 36.5667,
#   'Max Temp': 64.83,
#   'Humidity': 89,
#   'Cloudiness': 72,
#   'Wind Speed': 6.78,
#   'Current Description': 'light rain'},
#  {'City': 'Margate',
#   'Country': 'GB',
#   'Lat': 51.3813,
#   'Lng': 1.3862,
#   'Max Temp': 55.69,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Gashua',
#   'Country': 'NG',
#   'Lat': 12.871,
#   'Lng': 11.0482,
#   'Max Temp': 105.21,
#   'Humidity': 15,
#   'Cloudiness': 89,
#   'Wind Speed': 7.16,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Seoul',
#   'Country': 'KR',
#   'Lat': 37.5683,
#   'Lng': 126.9778,
#   'Max Temp': 51.37,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Current Description': 'clear sky'},
#  {'City': 'Camana',
#   'Country': 'PE',
#   'Lat': -16.6228,
#   'Lng': -72.7111,
#   'Max Temp': 69.89,
#   'Humidity': 75,
#   'Cloudiness': 73,
#   'Wind Speed': 9.66,
#   'Current Description': 'broken clouds'},
#  {'City': 'Aykhal',
#   'Country': 'RU',
#   'Lat': 66,
#   'Lng': 111.5,
#   'Max Temp': -4.83,
#   'Humidity': 100,
#   'Cloudiness': 100,
# ...
#   'Lng': 91.6419,
#   'Max Temp': 33.8,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 6.87,
#   'Current Description': 'clear sky'},
#  {'City': 'Cururupu',
#   'Country': 'BR',
#   'Lat': -1.8283,
#   'Lng': -44.8683,
#   'Max Temp': 82.06,
#   'Humidity': 82,
#   'Cloudiness': 98,
#   'Wind Speed': 5.17,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vagamo',
#   'Country': 'NO',
#   'Lat': 61.8751,
#   'Lng': 9.0967,
#   'Max Temp': 42.69,
#   'Humidity': 76,
#   'Cloudiness': 20,
#   'Wind Speed': 1.23,
#   'Current Description': 'few clouds'},
#  {'City': 'Sinnamary',
#   'Country': 'GF',
#   'Lat': 5.3833,
#   'Lng': -52.95,
#   'Max Temp': 81.73,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 11.27,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Belluno',
#   'Country': 'IT',
#   'Lat': 46.145,
#   'Lng': 12.2214,
#   'Max Temp': 69.42,
#   'Humidity': 51,
#   'Cloudiness': 99,
#   'Wind Speed': 7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tura',
#   'Country': 'IN',
#   'Lat': 25.5198,
#   'Lng': 90.2201,
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 8.77,
#   'Current Description': 'clear sky'},
#  {'City': 'Suluq',
#   'Country': 'LY',
#   'Lat': 31.6682,
#   'Lng': 20.2521,
#   'Max Temp': 80.01,
#   'Humidity': 17,
#   'Cloudiness': 100,
#   'Wind Speed': 38.23,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Petrozavodsk',
#   'Country': 'RU',
#   'Lat': 61.7849,
#   'Lng': 34.3469,
#   'Max Temp': 42.26,
#   'Humidity': 60,
#   'Cloudiness': 75,
#   'Wind Speed': 11.18,
#   'Current Description': 'broken clouds'},
#  {'City': 'Saint-Pierre',
#   'Country': 'RE',
#   'Lat': -21.3393,
#   'Lng': 55.4781,
#   'Max Temp': 78.48,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 20.71,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bilibino',
#   'Country': 'RU',
#   'Lat': 68.0546,
#   'Lng': 166.4372,
#   'Max Temp': 4.84,
#   'Humidity': 94,
#   'Cloudiness': 21,
#   'Wind Speed': 4.99,
#   'Current Description': 'few clouds'},
#  {'City': 'Aketi',
#   'Country': 'CD',
#   'Lat': 2.7388,
#   'Lng': 23.7833,
#   'Max Temp': 82.06,
#   'Humidity': 58,
#   'Cloudiness': 100,
#   'Wind Speed': 3.6,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saravan',
#   'Country': 'AM',
#   'Lat': 39.7196,
#   'Lng': 45.6483,
#   'Max Temp': 44.64,
#   'Humidity': 56,
#   'Cloudiness': 5,
#   'Wind Speed': 2.06,
#   'Current Description': 'clear sky'},
#  {'City': 'Arua',
#   'Country': 'UG',
#   'Lat': 3.0201,
#   'Lng': 30.9111,
#   'Max Temp': 70.14,
#   'Humidity': 85,
#   'Cloudiness': 96,
#   'Wind Speed': 5.66,
#   'Current Description': 'moderate rain'},
#  {'City': 'Liusha',
#   'Country': 'CN',
#   'Lat': 27.2098,
#   'Lng': 108.59,
#   'Max Temp': 43.27,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 5.73,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Guaiba',
#   'Country': 'BR',
#   'Lat': -30.1139,
#   'Lng': -51.325,
#   'Max Temp': 64.29,
#   'Humidity': 85,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Current Description': 'broken clouds'},
#  {'City': 'Praya',
#   'Country': 'CV',
#   'Lat': 14.9215,
#   'Lng': -23.5087,
#   'Max Temp': 79.34,
#   'Humidity': 50,
#   'Cloudiness': 20,
#   'Wind Speed': 19.57,
#   'Current Description': 'few clouds'},
#  {'City': 'Severnyy',
#   'Country': 'RU',
#   'Lat': 50.677,
#   'Lng': 36.5532,
#   'Max Temp': 60.84,
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 6.71,
#   'Current Description': 'clear sky'},
#  {'City': 'Antalaha',
#   'Country': 'MG',
#   'Lat': -14.9003,
#   'Lng': 50.2788,
#   'Max Temp': 79.5,
#   'Humidity': 82,
#   'Cloudiness': 99,
#   'Wind Speed': 9.73,
#   'Current Description': 'light rain'},
#  {'City': 'Yenagoa',
#   'Country': 'NG',
#   'Lat': 4.9247,
#   'Lng': 6.2642,
#   'Max Temp': 90.16,
#   'Humidity': 54,
#   'Cloudiness': 100,
#   'Wind Speed': 8.23,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Yunhe',
#   'Country': 'CN',
#   'Lat': 34.0833,
#   'Lng': 119.7167,
#   'Max Temp': 49.48,
#   'Humidity': 43,
#   'Cloudiness': 100,
#   'Wind Speed': 9.82,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mandalgovi',
#   'Country': 'MN',
#   'Lat': 45.7625,
#   'Lng': 106.2708,
#   'Max Temp': 32.2,
#   'Humidity': 39,
#   'Cloudiness': 78,
#   'Wind Speed': 2.08,
#   'Current Description': 'broken clouds'},
#  {'City': 'Fukue',
#   'Country': 'JP',
#   'Lat': 32.6881,
#   'Lng': 128.8419,
#   'Max Temp': 56.28,
#   'Humidity': 68,
#   'Cloudiness': 92,
#   'Wind Speed': 24.34,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mitu',
#   'Country': 'CO',
#   'Lat': 1.1983,
#   'Lng': -70.1733,
#   'Max Temp': 78.26,
#   'Humidity': 78,
#   'Cloudiness': 97,
#   'Wind Speed': 2.75,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tidman',
#   'Country': 'PH',
#   'Lat': 8.2986,
#   'Lng': 126.3389,
#   'Max Temp': 76.41,
#   'Humidity': 86,
#   'Cloudiness': 63,
#   'Wind Speed': 0.63,
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Metro',
#   'Country': 'ID',
#   'Lat': -5.1131,
#   'Lng': 105.3067,
#   'Max Temp': 75.96,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 1.9,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lulindi',
#   'Country': 'TZ',
#   'Lat': -10.8167,
#   'Lng': 39.1333,
#   'Max Temp': 74.01,
#   'Humidity': 94,
#   'Cloudiness': 61,
#   'Wind Speed': 4.56,
#   'Current Description': 'light rain'},
#  {'City': 'Palu',
#   'Country': 'ID',
#   'Lat': -0.8917,
#   'Lng': 119.8707,
#   'Max Temp': 76.33,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 1.79,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vanderhoof',
#   'Country': 'CA',
#   'Lat': 54.0166,
#   'Lng': -124.0198,
#   'Max Temp': 23.76,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 3.38,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dzhebariki-Khaya',
#   'Country': 'RU',
#   'Lat': 62.2167,
#   'Lng': 135.8,
#   'Max Temp': 1.65,
#   'Humidity': 98,
#   'Cloudiness': 34,
#   'Wind Speed': 2.44,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bundaberg',
#   'Country': 'AU',
#   'Lat': -24.85,
#   'Lng': 152.35,
#   'Max Temp': 65.21,
#   'Humidity': 91,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Jumla',
#   'Country': 'NP',
#   'Lat': 29.2747,
#   'Lng': 82.1838,
#   'Max Temp': 50.9,
#   'Humidity': 50,
#   'Cloudiness': 68,
#   'Wind Speed': 6.11,
#   'Current Description': 'broken clouds'},
#  {'City': 'Hobyo',
#   'Country': 'SO',
#   'Lat': 5.3505,
#   'Lng': 48.5268,
#   'Max Temp': 84.07,
#   'Humidity': 65,
#   'Cloudiness': 86,
#   'Wind Speed': 10.98,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Penzance',
#   'Country': 'GB',
#   'Lat': 50.1186,
#   'Lng': -5.5371,
#   'Max Temp': 56.52,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Current Description': 'few clouds'},
#  {'City': 'San Ramon',
#   'Country': 'US',
#   'Lat': 37.7799,
#   'Lng': -121.978,
#   'Max Temp': 50.58,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Henties Bay',
#   'Country': 'NA',
#   'Lat': -22.116,
#   'Lng': 14.2845,
#   'Max Temp': 62.24,
#   'Humidity': 77,
#   'Cloudiness': 3,
#   'Wind Speed': 13.49,
#   'Current Description': 'clear sky'},
#  {'City': 'Misratah',
#   'Country': 'LY',
#   'Lat': 32.3754,
#   'Lng': 15.0925,
#   'Max Temp': 70.23,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 10.45,
#   'Current Description': 'clear sky'},
#  {'City': 'Pangnirtung',
#   'Country': 'CA',
#   'Lat': 66.1451,
#   'Lng': -65.7125,
#   'Max Temp': 3.7,
#   'Humidity': 84,
#   'Cloudiness': 13,
#   'Wind Speed': 3.76,
#   'Current Description': 'few clouds'},
#  {'City': 'Syamzha',
#   'Country': 'RU',
#   'Lat': 60.0158,
#   'Lng': 41.0614,
#   'Max Temp': 38.08,
#   'Humidity': 77,
#   'Cloudiness': 77,
#   'Wind Speed': 3.65,
#   'Current Description': 'broken clouds'},
#  {'City': 'Moa',
#   'Country': 'CU',
#   'Lat': 20.6569,
#   'Lng': -74.9403,
#   'Max Temp': 82.54,
#   'Humidity': 68,
#   'Cloudiness': 42,
#   'Wind Speed': 12.86,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mata',
#   'Country': 'PT',
#   'Lat': 40.683,
#   'Lng': -7.4592,
#   'Max Temp': 77.59,
#   'Humidity': 38,
#   'Cloudiness': 38,
#   'Wind Speed': 2.08,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Otane',
#   'Country': 'NZ',
#   'Lat': -39.8833,
#   'Lng': 176.6333,
#   'Max Temp': 46,
#   'Humidity': 91,
#   'Cloudiness': 4,
#   'Wind Speed': 2.06,
#   'Current Description': 'clear sky'},
#  {'City': 'Ust-Charyshskaya Pristan',
#   'Country': 'RU',
#   'Lat': 52.3934,
#   'Lng': 83.6635,
#   'Max Temp': 53.44,
#   'Humidity': 36,
#   'Cloudiness': 7,
#   'Wind Speed': 4.79,
#   'Current Description': 'clear sky'},
#  {'City': 'San Quintin',
#   'Country': 'MX',
#   'Lat': 30.4833,
#   'Lng': -115.95,
#   'Max Temp': 59.02,
#   'Humidity': 76,
#   'Cloudiness': 96,
#   'Wind Speed': 13.22,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sao Luis De Montes Belos',
#   'Country': 'BR',
#   'Lat': -16.525,
#   'Lng': -50.3722,
#   'Max Temp': 82,
#   'Humidity': 58,
#   'Cloudiness': 28,
#   'Wind Speed': 5.7,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Phalaborwa',
#   'Country': 'ZA',
#   'Lat': -23.943,
#   'Lng': 31.1411,
#   'Max Temp': 90.99,
#   'Humidity': 29,
#   'Cloudiness': 72,
#   'Wind Speed': 4.65,
#   'Current Description': 'broken clouds'},
#  {'City': 'Thinadhoo',
#   'Country': 'MV',
#   'Lat': 0.5333,
#   'Lng': 72.9333,
#   'Max Temp': 84.24,
#   'Humidity': 64,
#   'Cloudiness': 11,
#   'Wind Speed': 0.56,
#   'Current Description': 'few clouds'},
#  {'City': 'Popondetta',
#   'Country': 'PG',
#   'Lat': -8.7537,
#   'Lng': 148.2534,
#   'Max Temp': 73.72,
#   'Humidity': 93,
#   'Cloudiness': 60,
#   'Wind Speed': 2.98,
#   'Current Description': 'broken clouds'},
#  {'City': 'Wanaka',
#   'Country': 'NZ',
#   'Lat': -44.7,
#   'Lng': 169.15,
#   'Max Temp': 51.8,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 8.16,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Great Falls',
#   'Country': 'US',
#   'Lat': 47.5002,
#   'Lng': -111.3008,
#   'Max Temp': 19.17,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Current Description': 'mist'},
#  {'City': 'Staryy Nadym',
#   'Country': 'RU',
#   'Lat': 65.6118,
#   'Lng': 72.6842,
#   'Max Temp': 27.64,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 9.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Awash',
#   'Country': 'ET',
#   'Lat': 8.9833,
#   'Lng': 40.1667,
#   'Max Temp': 87.96,
#   'Humidity': 39,
#   'Cloudiness': 95,
#   'Wind Speed': 19.13,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Hardy',
#   'Country': 'CA',
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp': 37.22,
#   'Humidity': 65,
#   'Cloudiness': 68,
#   'Wind Speed': 3.49,
#   'Current Description': 'broken clouds'},
#  {'City': 'Amaga',
#   'Country': 'CO',
#   'Lat': 6.04,
#   'Lng': -75.7031,
#   'Max Temp': 80.37,
#   'Humidity': 66,
#   'Cloudiness': 86,
#   'Wind Speed': 2.59,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Porto Nacional',
#   'Country': 'BR',
#   'Lat': -10.7081,
#   'Lng': -48.4172,
#   'Max Temp': 86,
#   'Humidity': 62,
#   'Cloudiness': 85,
#   'Wind Speed': 2.95,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dharchula',
#   'Country': 'IN',
#   'Lat': 29.85,
#   'Lng': 80.5333,
#   'Max Temp': 66.04,
#   'Humidity': 33,
#   'Cloudiness': 87,
#   'Wind Speed': 7.02,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hirara',
#   'Country': 'JP',
#   'Lat': 24.8,
#   'Lng': 125.2833,
#   'Max Temp': 71.85,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 27.11,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hampton',
#   'Country': 'US',
#   'Lat': 37.0299,
#   'Lng': -76.3452,
#   'Max Temp': 68.02,
#   'Humidity': 38,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Current Description': 'broken clouds'},
#  {'City': 'Fairbanks',
#   'Country': 'US',
#   'Lat': 64.8378,
#   'Lng': -147.7164,
#   'Max Temp': 25.14,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Current Description': 'clear sky'},
#  {'City': 'Mayo',
#   'Country': 'US',
#   'Lat': 38.8876,
#   'Lng': -76.5119,
#   'Max Temp': 68.67,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 5.01,
#   'Current Description': 'clear sky'},
#  {'City': 'Homer',
#   'Country': 'US',
#   'Lat': 59.6425,
#   'Lng': -151.5483,
#   'Max Temp': 39.07,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 17,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Shache',
#   'Country': 'CN',
#   'Lat': 38.4167,
#   'Lng': 77.2406,
#   'Max Temp': 69.28,
#   'Humidity': 18,
#   'Cloudiness': 1,
#   'Wind Speed': 6.73,
#   'Current Description': 'clear sky'},
#  {'City': 'Byron Bay',
#   'Country': 'AU',
#   'Lat': -28.65,
#   'Lng': 153.6167,
#   'Max Temp': 62.94,
#   'Humidity': 73,
#   'Cloudiness': 15,
#   'Wind Speed': 10.09,
#   'Current Description': 'few clouds'},
#  {'City': 'Ponoka',
#   'Country': 'CA',
#   'Lat': 52.6768,
#   'Lng': -113.5815,
#   'Max Temp': 21.83,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 6.8,
#   'Current Description': 'light snow'},
#  {'City': 'Quelimane',
#   'Country': 'MZ',
#   'Lat': -17.8786,
#   'Lng': 36.8883,
#   'Max Temp': 80.08,
#   'Humidity': 87,
#   'Cloudiness': 13,
#   'Wind Speed': 7.38,
#   'Current Description': 'few clouds'},
#  {'City': 'Uyuni',
#   'Country': 'BO',
#   'Lat': -20.4597,
#   'Lng': -66.825,
#   'Max Temp': 52.59,
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 20.51,
#   'Current Description': 'clear sky'},
#  {'City': 'Koumac',
#   'Country': 'NC',
#   'Lat': -20.5667,
#   'Lng': 164.2833,
#   'Max Temp': 73.11,
#   'Humidity': 87,
#   'Cloudiness': 88,
#   'Wind Speed': 1.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sabzevar',
#   'Country': 'IR',
#   'Lat': 36.2126,
#   'Lng': 57.6819,
#   'Max Temp': 78.78,
#   'Humidity': 19,
#   'Cloudiness': 100,
#   'Wind Speed': 5.23,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Forbes',
#   'Country': 'AU',
#   'Lat': -33.3833,
#   'Lng': 148.0167,
#   'Max Temp': 58.91,
#   'Humidity': 60,
#   'Cloudiness': 89,
#   'Wind Speed': 4.5,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Srednekolymsk',
#   'Country': 'RU',
#   'Lat': 67.45,
#   'Lng': 153.6833,
#   'Max Temp': 10.89,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3.13,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Samarkand',
#   'Country': 'UZ',
#   'Lat': 39.6542,
#   'Lng': 66.9597,
#   'Max Temp': 72.82,
#   'Humidity': 40,
#   'Cloudiness': 7,
#   'Wind Speed': 9.22,
#   'Current Description': 'clear sky'},
#  {'City': 'Santa Maria',
#   'Country': 'BR',
#   'Lat': -29.6842,
#   'Lng': -53.8069,
#   'Max Temp': 64.11,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 5.3,
#   'Current Description': 'clear sky'},
#  {'City': 'Naron',
#   'Country': 'ES',
#   'Lat': 43.5167,
#   'Lng': -8.1528,
#   'Max Temp': 68.56,
#   'Humidity': 66,
#   'Cloudiness': 4,
#   'Wind Speed': 6.53,
#   'Current Description': 'clear sky'},
#  {'City': 'Christchurch',
#   'Country': 'NZ',
#   'Lat': -43.5333,
#   'Lng': 172.6333,
#   'Max Temp': 54.91,
#   'Humidity': 91,
#   'Cloudiness': 19,
#   'Wind Speed': 4.61,
#   'Current Description': 'fog'},
#  {'City': 'Mogadishu',
#   'Country': 'SO',
#   'Lat': 2.0371,
#   'Lng': 45.3438,
#   'Max Temp': 83.3,
#   'Humidity': 74,
#   'Cloudiness': 97,
#   'Wind Speed': 14.52,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kidal',
#   'Country': 'ML',
#   'Lat': 18.4411,
#   'Lng': 1.4078,
#   'Max Temp': 101.37,
#   'Humidity': 6,
#   'Cloudiness': 66,
#   'Wind Speed': 18.43,
#   'Current Description': 'broken clouds'},
#  {'City': 'Margosatubig',
#   'Country': 'PH',
#   'Lat': 7.5777,
#   'Lng': 123.1658,
#   'Max Temp': 78.04,
#   'Humidity': 86,
#   'Cloudiness': 43,
#   'Wind Speed': 2.48,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Half Moon Bay',
#   'Country': 'US',
#   'Lat': 37.4636,
#   'Lng': -122.4286,
#   'Max Temp': 52.83,
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Current Description': 'clear sky'},
#  {'City': 'Marovoay',
#   'Country': 'MG',
#   'Lat': -16.1,
#   'Lng': 46.6333,
#   'Max Temp': 84.07,
#   'Humidity': 64,
#   'Cloudiness': 8,
#   'Wind Speed': 7.81,
#   'Current Description': 'clear sky'},
#  {'City': 'Taiyuan',
#   'Country': 'CN',
#   'Lat': 37.8694,
#   'Lng': 112.5603,
#   'Max Temp': 46.26,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Current Description': 'clear sky'},
#  {'City': 'Skibbereen',
#   'Country': 'IE',
#   'Lat': 51.55,
#   'Lng': -9.2667,
#   'Max Temp': 54.1,
#   'Humidity': 73,
#   'Cloudiness': 2,
#   'Wind Speed': 9.69,
#   'Current Description': 'clear sky'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Albany      US  42.6001  -73.9662     59.29        27           1
# 1        Jamestown      US  42.0970  -79.2353     57.02        30          20
# 2             Lebu      CL -37.6167  -73.6500     57.90        70          69
# 3            Ukiah      US  39.1502 -123.2078     41.38        95         100
# 4            Kapaa      US  22.0752 -159.3190     71.92        80          40
# ..             ...     ...      ...       ...       ...       ...         ...
# 686   Margosatubig      PH   7.5777  123.1658     78.04        86          43
# 687  Half Moon Bay      US  37.4636 -122.4286     52.83        84           0
# 688       Marovoay      MG -16.1000   46.6333     84.07        64           8
# 689        Taiyuan      CN  37.8694  112.5603     46.26        39           0
# 690     Skibbereen      IE  51.5500   -9.2667     54.10        73           2
#
#      Wind Speed Current Description
# 0          3.00           clear sky
# 1         17.27          few clouds
# 2          7.14       broken clouds
# 3          0.00     overcast clouds
# 4         16.11    scattered clouds
# ..          ...                 ...
# 686        2.48    scattered clouds
# 687        9.22           clear sky
# 688        7.81           clear sky
# 689        2.24           clear sky
# 690        9.69           clear sky
#
# [691 rows x 9 columns]

# %%
# Create an output file to save the DataFrame as a CSV 
# in a new folder "weather_data" for that file.
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV with the index label (or column A) header as "City_ID."
# If we ever need to export the CSV file to a DataFrame, that header will be present in the DataFrame.
city_data_df.to_csv(output_data_file, index_label="City_ID")
